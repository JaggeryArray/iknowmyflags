# %%
import os
import numpy as np
import cv2
from PIL import Image
import cairosvg
import io
from collections import Counter
import colorsys
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

class FlagFeatureExtractor:
    def __init__(self, target_size=(128, 64)):
        self.target_size = target_size
        
    def load_flag_from_svg(self, svg_path, remove_padding=True):
        """Load and preprocess flag from SVG"""
        png_bytes = cairosvg.svg2png(
            url=svg_path, 
            output_width=self.target_size[0], 
            output_height=self.target_size[1]
        )
        img = Image.open(io.BytesIO(png_bytes)).convert("RGB")
        img_array = np.array(img) / 255.0
        
        if remove_padding:
            img_array = self.remove_black_padding(img_array)
            
        return img_array
    
    def remove_black_padding(self, img_array, threshold=0.05):
        """Remove black padding from flag image"""
        # Find non-black pixels
        mask = np.any(img_array > threshold, axis=2)
        
        if not np.any(mask):
            return img_array
            
        # Find bounding box
        coords = np.argwhere(mask)
        y0, x0 = coords.min(axis=0)
        y1, x1 = coords.max(axis=0)
        
        # Crop to content
        return img_array[y0:y1+1, x0:x1+1]
    
    def extract_color_features(self, img_array):
        """Extract color-based features"""
        features = {}
        
        # Reshape for analysis
        pixels = img_array.reshape(-1, 3)
        
        # Dominant colors using K-means
        n_colors = min(8, len(np.unique(pixels.reshape(-1, pixels.shape[-1]), axis=0)))
        if n_colors > 1:
            kmeans = KMeans(n_clusters=n_colors, random_state=42, n_init=10)
            kmeans.fit(pixels)
            dominant_colors = kmeans.cluster_centers_
            color_proportions = np.bincount(kmeans.labels_) / len(kmeans.labels_)
        else:
            dominant_colors = [pixels[0]]
            color_proportions = [1.0]
        
        # Color categories
        color_categories = []
        for color in dominant_colors:
            h, s, v = colorsys.rgb_to_hsv(*color)
            category = self.categorize_color(h, s, v)
            color_categories.append(category)
        
        features['dominant_colors'] = dominant_colors
        features['color_proportions'] = color_proportions
        features['color_categories'] = Counter(color_categories)
        features['num_colors'] = len(dominant_colors)
        
        # Color distribution statistics
        features['brightness'] = np.mean(pixels)
        features['color_variance'] = np.var(pixels)
        
        return features
    
    def categorize_color(self, h, s, v):
        """Categorize RGB color into semantic categories"""
        if s < 0.2:  # Low saturation
            if v < 0.3:
                return 'black'
            elif v > 0.8:
                return 'white'
            else:
                return 'gray'
        
        # High saturation colors by hue
        if h < 0.05 or h > 0.95:
            return 'red'
        elif 0.05 <= h < 0.15:
            return 'orange'
        elif 0.15 <= h < 0.25:
            return 'yellow'
        elif 0.25 <= h < 0.4:
            return 'green'
        elif 0.4 <= h < 0.65:
            return 'blue'
        elif 0.65 <= h < 0.8:
            return 'purple'
        else:
            return 'pink'
    
    def extract_geometric_features(self, img_array):
        """Extract geometric and structural features"""
        features = {}
        
        # Convert to grayscale for edge detection
        if len(img_array.shape) == 3:
            gray = cv2.cvtColor((img_array * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY)
        else:
            gray = (img_array * 255).astype(np.uint8)
        
        # Edge detection
        edges = cv2.Canny(gray, 50, 150)
        features['edge_density'] = np.sum(edges > 0) / edges.size
        
        # Line detection
        lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=20, minLineLength=10, maxLineGap=5)
        
        if lines is not None:
            features['num_lines'] = len(lines)
            
            # Classify line orientations
            horizontal_lines = 0
            vertical_lines = 0
            diagonal_lines = 0
            
            for line in lines:
                x1, y1, x2, y2 = line[0]
                angle = np.abs(np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi)
                
                if angle < 15 or angle > 165:
                    horizontal_lines += 1
                elif 75 < angle < 105:
                    vertical_lines += 1
                else:
                    diagonal_lines += 1
            
            features['horizontal_lines'] = horizontal_lines
            features['vertical_lines'] = vertical_lines
            features['diagonal_lines'] = diagonal_lines
        else:
            features['num_lines'] = 0
            features['horizontal_lines'] = 0
            features['vertical_lines'] = 0
            features['diagonal_lines'] = 0
        
        # Contour analysis for shapes
        contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        features['num_shapes'] = len(contours)
        
        # Analyze shape complexity
        if contours:
            areas = [cv2.contourArea(c) for c in contours if cv2.contourArea(c) > 10]
            perimeters = [cv2.arcLength(c, True) for c in contours if cv2.contourArea(cv2.approxPolyDP(c, 0.02*cv2.arcLength(c, True), True)) > 10]
            
            if areas and perimeters:
                features['avg_shape_complexity'] = np.mean([p**2/(4*np.pi*a) if a > 0 else 0 for a, p in zip(areas, perimeters)])
                features['shape_size_variance'] = np.var(areas) if len(areas) > 1 else 0
            else:
                features['avg_shape_complexity'] = 0
                features['shape_size_variance'] = 0
        
        return features
    
    def extract_pattern_features(self, img_array):
        """Extract pattern-based features"""
        features = {}
        
        # Stripe detection
        features.update(self.detect_stripes(img_array))
        
        # Symmetry analysis
        features.update(self.analyze_symmetry(img_array))
        
        # Quarter analysis (for crosses, unions, etc.)
        features.update(self.analyze_quarters(img_array))
        
        return features
    
    def detect_stripes(self, img_array):
        """Detect horizontal and vertical stripes"""
        features = {}
        h, w = img_array.shape[:2]
        
        # Horizontal stripe detection
        row_colors = []
        for i in range(h):
            row_avg = np.mean(img_array[i, :], axis=0)
            row_colors.append(row_avg)
        
        # Count color changes (indicates stripes)
        horizontal_changes = 0
        for i in range(1, len(row_colors)):
            if np.linalg.norm(row_colors[i] - row_colors[i-1]) > 0.3:
                horizontal_changes += 1
        
        features['horizontal_stripes'] = horizontal_changes
        
        # Vertical stripe detection
        col_colors = []
        for j in range(w):
            col_avg = np.mean(img_array[:, j], axis=0)
            col_colors.append(col_avg)
        
        vertical_changes = 0
        for j in range(1, len(col_colors)):
            if np.linalg.norm(col_colors[j] - col_colors[j-1]) > 0.3:
                vertical_changes += 1
                
        features['vertical_stripes'] = vertical_changes
        
        # Determine stripe pattern type
        if horizontal_changes > vertical_changes and horizontal_changes > 2:
            features['stripe_type'] = 'horizontal'
        elif vertical_changes > horizontal_changes and vertical_changes > 2:
            features['stripe_type'] = 'vertical'
        elif horizontal_changes > 0 and vertical_changes > 0:
            features['stripe_type'] = 'both'
        else:
            features['stripe_type'] = 'none'
            
        return features
    
    def analyze_symmetry(self, img_array):
        """Analyze horizontal and vertical symmetry"""
        features = {}
        
        h, w = img_array.shape[:2]
        
        # Horizontal symmetry (top-bottom)
        top_half = img_array[:h//2, :]
        bottom_half = np.flip(img_array[h//2:], axis=0)
        min_h = min(top_half.shape[0], bottom_half.shape[0])
        
        if min_h > 0:
            h_symmetry = 1 - np.mean(np.abs(top_half[:min_h] - bottom_half[:min_h]))
            features['horizontal_symmetry'] = max(0, h_symmetry)
        else:
            features['horizontal_symmetry'] = 0
        
        # Vertical symmetry (left-right)
        left_half = img_array[:, :w//2]
        right_half = np.flip(img_array[:, w//2:], axis=1)
        min_w = min(left_half.shape[1], right_half.shape[1])
        
        if min_w > 0:
            v_symmetry = 1 - np.mean(np.abs(left_half[:, :min_w] - right_half[:, :min_w]))
            features['vertical_symmetry'] = max(0, v_symmetry)
        else:
            features['vertical_symmetry'] = 0
            
        return features
    
    def analyze_quarters(self, img_array):
        """Analyze flag quarters for crosses, unions, etc."""
        features = {}
        
        h, w = img_array.shape[:2]
        
        # Divide into quarters
        q1 = img_array[:h//2, :w//2]  # top-left
        q2 = img_array[:h//2, w//2:]  # top-right  
        q3 = img_array[h//2:, :w//2]  # bottom-left
        q4 = img_array[h//2:, w//2:]  # bottom-right
        
        quarters = [q1, q2, q3, q4]
        
        # Calculate average color of each quarter
        quarter_colors = [np.mean(q, axis=(0,1)) for q in quarters]
        
        # Check for cross patterns (opposite quarters similar)
        cross_similarity = (
            np.linalg.norm(quarter_colors[0] - quarter_colors[3]) + 
            np.linalg.norm(quarter_colors[1] - quarter_colors[2])
        ) / 2
        
        features['cross_pattern'] = 1 - min(cross_similarity, 1.0)
        
        # Check for union jack pattern (quarters different)
        quarter_variance = np.var([np.linalg.norm(qc) for qc in quarter_colors])
        features['quarter_diversity'] = min(quarter_variance, 1.0)
        
        return features
    
    def extract_all_features(self, img_array):
        """Extract all feature categories"""
        all_features = {}
        
        all_features.update(self.extract_color_features(img_array))
        all_features.update(self.extract_geometric_features(img_array))
        all_features.update(self.extract_pattern_features(img_array))
        
        return all_features
    
    def analyze_flag_directory(self, svg_dir):
        """Analyze all flags in directory"""
        results = {}
        
        for filename in os.listdir(svg_dir):
            if filename.endswith('.svg'):
                code = filename.split('.')[0]
                svg_path = os.path.join(svg_dir, filename)
                
                try:
                    img_array = self.load_flag_from_svg(svg_path)
                    features = self.extract_all_features(img_array)
                    results[code] = features
                    print(f"Analyzed {code}")
                except Exception as e:
                    print(f"Error analyzing {code}: {e}")
        
        return results
    
    def print_feature_summary(self, features, flag_code):
        """Print a readable summary of flag features"""
        print(f"\n=== FLAG FEATURES: {flag_code.upper()} ===")
        
        # Color features
        print(f"Colors: {features['num_colors']} dominant colors")
        print(f"Color categories: {dict(features['color_categories'])}")
        print(f"Brightness: {features['brightness']:.2f}")
        
        # Geometric features  
        print(f"Lines: {features['num_lines']} total ({features['horizontal_lines']} horiz, {features['vertical_lines']} vert)")
        print(f"Shapes: {features['num_shapes']}")
        print(f"Edge density: {features['edge_density']:.3f}")
        
        # Pattern features
        print(f"Stripe type: {features['stripe_type']}")
        print(f"Stripes: {features['horizontal_stripes']} horiz, {features['vertical_stripes']} vert")
        print(f"Symmetry: {features['horizontal_symmetry']:.2f} horiz, {features['vertical_symmetry']:.2f} vert")
        print(f"Cross pattern: {features['cross_pattern']:.2f}")

# Example usage
if __name__ == "__main__":
    # Initialize extractor
    extractor = FlagFeatureExtractor()
    
    # Analyze single flag
    svg_path = "sovereign_flag_svgs"  # Replace with actual path
    # img_array = extractor.load_flag_from_svg(svg_path)
    # features = extractor.extract_all_features(img_array)
    # extractor.print_feature_summary(features, "example")
    
    # Analyze whole directory
    # results = extractor.analyze_flag_directory("sovereign_flag_svgs")
    
    print("Flag feature extractor ready!")
    print("Use extractor.analyze_flag_directory('your_svg_dir') to analyze all flags")
# Out:
# Flag feature extractor ready!
# Use extractor.analyze_flag_directory('your_svg_dir') to analyze all flags

# %%
extractor.analyze_flag_directory("sovereign_flag_svgs")
# Out:
# Analyzed ad
# Analyzed ae
# Analyzed af
# Analyzed ag
# Analyzed al
# Analyzed am
# Analyzed ao
# Analyzed ar
# Analyzed at
# Analyzed au
# Analyzed az
# Analyzed ba
# Analyzed bb
# Analyzed bd
# Analyzed be
# Analyzed bf
# Analyzed bg
# Analyzed bh
# Analyzed bi
# Analyzed bj
# Analyzed bn
# Analyzed bo
# Analyzed br
# Analyzed bs
# Analyzed bt
# Analyzed bw
# Analyzed by
# Analyzed bz
# Analyzed ca
# Analyzed cd
# Analyzed cf
# Analyzed cg
# Analyzed ch
# Analyzed ci
# Analyzed cl
# Analyzed cm
# Analyzed cn
# Analyzed co
# Analyzed cr
# Analyzed cu
# Analyzed cv
# Analyzed cy
# Analyzed cz
# Analyzed de
# Analyzed dj
# Analyzed dk
# Analyzed dm
# Analyzed do
# Analyzed dz
# Analyzed ec
# Analyzed ee
# Analyzed eg
# Analyzed er
# Analyzed es
# Analyzed et
# Analyzed fi
# Analyzed fj
# Analyzed fm
# Analyzed fr
# Analyzed ga
# Analyzed gb
# Analyzed gd
# Analyzed ge
# Analyzed gh
# Analyzed gm
# Analyzed gn
# Analyzed gq
# Analyzed gr
# Analyzed gt
# Analyzed gw
# Analyzed gy
# Analyzed hn
# Analyzed hr
# Analyzed ht
# Analyzed hu
# Analyzed id
# Analyzed ie
# Analyzed il
# Analyzed in
# Analyzed iq
# Analyzed ir
# Analyzed is
# Analyzed it
# Analyzed jm
# Analyzed jo
# Analyzed jp
# Analyzed ke
# Analyzed kg
# Analyzed kh
# Analyzed ki
# Analyzed km
# Analyzed kn
# Analyzed kp
# Analyzed kr
# Analyzed kw
# Analyzed kz
# Analyzed la
# Analyzed lb
# Analyzed lc
# Analyzed li
# Analyzed lk
# Analyzed lr
# Analyzed ls
# Analyzed lt
# Analyzed lu
# Analyzed lv
# Analyzed ly
# Analyzed ma
# Analyzed mc
# Analyzed md
# Analyzed me
# Analyzed mg
# Analyzed mh
# Analyzed mk
# Analyzed ml
# Analyzed mm
# Analyzed mn
# Analyzed mr
# Analyzed mt
# Analyzed mu
# Analyzed mv
# Analyzed mw
# Analyzed mx
# Analyzed my
# Analyzed mz
# Analyzed na
# Analyzed ne
# Analyzed ng
# Analyzed ni
# Analyzed nl
# Analyzed no
# Analyzed np
# Analyzed nr
# Analyzed nz
# Analyzed om
# Analyzed pa
# Analyzed pe
# Analyzed pg
# Analyzed ph
# Analyzed pk
# Analyzed pl
# Analyzed ps
# Analyzed pt
# Analyzed pw
# Analyzed py
# Analyzed qa
# Analyzed ro
# Analyzed rs
# Analyzed ru
# Analyzed rw
# Analyzed sa
# Analyzed sb
# Analyzed sc
# Analyzed sd
# Analyzed se
# Analyzed sg
# Analyzed si
# Analyzed sk
# Analyzed sl
# Analyzed sm
# Analyzed sn
# Analyzed so
# Analyzed sr
# Analyzed ss
# Analyzed st
# Analyzed sv
# Analyzed sy
# Analyzed sz
# Analyzed td
# Analyzed tg
# Analyzed th
# Analyzed tj
# Analyzed tl
# Analyzed tm
# Analyzed tn
# Analyzed to
# Analyzed tr
# Analyzed tt
# Analyzed tv
# Analyzed tw
# Analyzed tz
# Analyzed ua
# Analyzed ug
# Analyzed us
# Analyzed uy
# Analyzed uz
# Analyzed va
# Analyzed vc
# Analyzed ve
# Analyzed vn
# Analyzed vu
# Analyzed ws
# Analyzed xk
# Analyzed ye
# Analyzed za
# Analyzed zm
# Analyzed zw
# {'ad': {'dominant_colors': array([[ 8.15696760e-01,  6.35273147e-02,  2.26838628e-01],
#          [-1.22124533e-15,  9.41176471e-02,  6.58823529e-01],
#          [ 9.94961098e-01,  8.72664841e-01,  9.59271825e-04],
#          [ 7.32956259e-01,  6.14199526e-01,  4.17539323e-01],
#          [ 8.90783140e-01,  4.33814723e-01,  1.12293061e-01],
#          [ 8.76930147e-01,  7.32138480e-01,  1.55238971e-01],
#          [ 2.54901961e-01,  2.54901961e-01,  4.98039216e-01],
#          [ 4.54901961e-01,  4.47058824e-01,  3.60784314e-01]]),
#   'color_proportions': array([0.31759511, 0.30434783, 0.24439538, 0.06182065, 0.02836277,
#          0.02173913, 0.01086957, 0.01086957]),
#   'color_categories': Counter({'orange': 4,
#            'red': 1,
#            'blue': 1,
#            'purple': 1,
#            'yellow': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.41666444657573176),
#   'color_variance': np.float64(0.1355512276792395),
#   'edge_density': np.float64(0.07489809782608696),
#   'num_lines': 4,
#   'horizontal_lines': 0,
#   'vertical_lines': 4,
#   'diagonal_lines': 0,
#   'num_shapes': 4,
#   'avg_shape_complexity': np.float64(1.410752095569493),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 5,
#   'stripe_type': 'vertical',
#   'horizontal_symmetry': np.float64(0.984493108837738),
#   'vertical_symmetry': np.float64(0.7202268044899119),
#   'cross_pattern': np.float64(0.41093305552242687),
#   'quarter_diversity': np.float64(0.018267761756077704)},
#  'ae': {'dominant_colors': array([[ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 3.49720253e-15,  3.44169138e-15,  6.10622664e-16],
#          [ 7.84313725e-01,  6.27450980e-02,  1.80392157e-01],
#          [-2.22044605e-16,  5.17647059e-01,  2.39215686e-01],
#          [ 6.66666667e-01,  6.66666667e-01,  6.66666667e-01],
#          [ 6.70588235e-01,  8.39215686e-01,  7.49019608e-01]]),
#   'color_proportions': array([0.234375  , 0.24609375, 0.25      , 0.24609375, 0.01171875,
#          0.01171875]),
#   'color_categories': Counter({'blue': 2,
#            'white': 1,
#            'yellow': 1,
#            'red': 1,
#            'gray': 1}),
#   'num_colors': 6,
#   'brightness': np.float64(0.39871834150326796),
#   'color_variance': np.float64(0.16828357217272036),
#   'edge_density': np.float64(0.0283203125),
#   'num_lines': 3,
#   'horizontal_lines': 2,
#   'vertical_lines': 1,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 4,
#   'vertical_stripes': 1,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.8738051470588235),
#   'vertical_symmetry': np.float64(0.7631433823529412),
#   'cross_pattern': np.float64(0.5953064655062509),
#   'quarter_diversity': np.float64(0.015002235550355897)},
#  'af': {'dominant_colors': array([[0.82933718, 0.13508362, 0.07693302],
#          [0.00238567, 0.47968401, 0.21364471],
#          [0.90851159, 0.53644162, 0.50522504],
#          [0.01281281, 0.01281281, 0.01281281],
#          [0.41371533, 0.6720512 , 0.52800975],
#          [0.35938206, 0.37095663, 0.36449198],
#          [0.87380098, 0.35954156, 0.3165516 ],
#          [0.970746  , 0.8517016 , 0.84164976]]),
#   'color_proportions': array([0.25672743, 0.40559896, 0.07638889, 0.07226562, 0.04188368,
#          0.03580729, 0.09244792, 0.01888021]),
#   'color_categories': Counter({'red': 3,
#            'blue': 2,
#            'black': 1,
#            'gray': 1,
#            'white': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.33388395288671024),
#   'color_variance': np.float64(0.08580421844974485),
#   'edge_density': np.float64(0.16666666666666666),
#   'num_lines': 20,
#   'horizontal_lines': 3,
#   'vertical_lines': 6,
#   'diagonal_lines': 11,
#   'num_shapes': 13,
#   'avg_shape_complexity': np.float64(213.24537952124606),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 2,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9278918164488017),
#   'vertical_symmetry': np.float64(0.662021718409586),
#   'cross_pattern': np.float64(0.3836726604796956),
#   'quarter_diversity': np.float64(0.01352858258816394)},
#  'ag': {'dominant_colors': array([[8.06893705e-01, 6.75722394e-02, 1.49940660e-01],
#          [2.10463564e-03, 7.30920260e-04, 3.11029898e-04],
#          [9.98968008e-01, 9.94840041e-01, 9.95252838e-01],
#          [9.16199813e-03, 4.46545285e-01, 7.70704949e-01],
#          [9.64413038e-01, 7.99859944e-01, 8.41991342e-02],
#          [5.11694678e-01, 4.02591036e-01, 8.16526611e-02],
#          [9.01960784e-01, 5.24585219e-01, 5.66515837e-01],
#          [2.76980929e-01, 1.24684394e-01, 3.80338437e-02]]),
#   'color_proportions': array([0.49479167, 0.24625651, 0.07421875, 0.109375  , 0.05013021,
#          0.00911458, 0.00423177, 0.01188151]),
#   'color_categories': Counter({'red': 3, 'orange': 3, 'white': 1, 'blue': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.3263420819716776),
#   'color_variance': np.float64(0.13845770641054964),
#   'edge_density': np.float64(0.062337239583333336),
#   'num_lines': 9,
#   'horizontal_lines': 3,
#   'vertical_lines': 0,
#   'diagonal_lines': 6,
#   'num_shapes': 7,
#   'avg_shape_complexity': np.float64(29.76236225123844),
#   'shape_size_variance': np.float64(49144.5),
#   'horizontal_stripes': 2,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.7355655977668845),
#   'vertical_symmetry': np.float64(0.9996289488017429),
#   'cross_pattern': np.float64(0.5022644040229063),
#   'quarter_diversity': np.float64(0.060023399920252574)},
#  'al': {'dominant_colors': array([[0.99971812, 0.        , 0.        ],
#          [0.00315011, 0.        , 0.        ],
#          [0.46152623, 0.        , 0.        ],
#          [0.75299211, 0.        , 0.        ],
#          [0.29863899, 0.        , 0.        ],
#          [0.60905298, 0.        , 0.        ],
#          [0.88296809, 0.        , 0.        ],
#          [0.12079248, 0.        , 0.        ]]),
#   'color_proportions': array([0.82361111, 0.08472222, 0.01284722, 0.01336806, 0.01475694,
#          0.01631944, 0.01770833, 0.01666667]),
#   'color_categories': Counter({'red': 8}),
#   'num_colors': 8,
#   'brightness': np.float64(0.2905455700798838),
#   'color_variance': np.float64(0.20060256450032535),
#   'edge_density': np.float64(0.06493055555555556),
#   'num_lines': 3,
#   'horizontal_lines': 2,
#   'vertical_lines': 1,
#   'diagonal_lines': 0,
#   'num_shapes': 21,
#   'avg_shape_complexity': np.float64(47.3718343090964),
#   'shape_size_variance': np.float64(4.0),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9641748366013072),
#   'vertical_symmetry': np.float64(0.999812091503268),
#   'cross_pattern': np.float64(0.9179547930283227),
#   'quarter_diversity': np.float64(0.0016828544732616945)},
#  'am': {'dominant_colors': array([[-6.66133815e-15,  2.00000000e-01,  6.27450980e-01],
#          [ 9.49019608e-01,  6.58823529e-01,  2.24820162e-15],
#          [ 8.50980392e-01, -1.72084569e-15,  7.05882353e-02],
#          [ 3.13725490e-01,  3.49019608e-01,  4.19607843e-01],
#          [ 2.82352941e-01,  1.33333333e-01,  4.43137255e-01]]),
#   'color_proportions': array([0.3125  , 0.328125, 0.328125, 0.015625, 0.015625]),
#   'color_categories': Counter({'blue': 2, 'orange': 1, 'red': 1, 'purple': 1}),
#   'num_colors': 5,
#   'brightness': np.float64(0.3729575163398693),
#   'color_variance': np.float64(0.13540608713528982),
#   'edge_density': np.float64(0.015625),
#   'num_lines': 1,
#   'horizontal_lines': 1,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 1,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 4,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.8161764705882353),
#   'vertical_symmetry': np.float64(1.0),
#   'cross_pattern': np.float64(0.5535878147402324),
#   'quarter_diversity': np.float64(0.011074454595152368)},
#  'ao': {'dominant_colors': array([[ 8.00173698e-01,  3.59621873e-02,  1.84146708e-01],
#          [ 3.38786402e-04,  2.69172758e-04, -3.88578059e-16],
#          [ 9.93198183e-01,  7.84557439e-01,  1.72814889e-03],
#          [ 6.14081996e-01,  4.88680927e-01, -4.16333634e-17],
#          [ 8.74811463e-01,  3.19356461e-01,  1.15233786e-01],
#          [ 1.51990493e-01,  1.21212121e-01, -4.16333634e-17],
#          [ 8.61722080e-01,  6.34185848e-01,  1.58567775e-02],
#          [ 3.75070028e-01,  2.98179272e-01, -1.38777878e-17]]),
#   'color_proportions': array([0.58794071, 0.33854167, 0.03545673, 0.0088141 , 0.0078125 ,
#          0.00661058, 0.00921474, 0.00560897]),
#   'color_categories': Counter({'orange': 6, 'red': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.23420950645215355),
#   'color_variance': np.float64(0.10471014027191407),
#   'edge_density': np.float64(0.06229967948717949),
#   'num_lines': 3,
#   'horizontal_lines': 1,
#   'vertical_lines': 0,
#   'diagonal_lines': 2,
#   'num_shapes': 5,
#   'avg_shape_complexity': np.float64(214.5739531640686),
#   'shape_size_variance': np.float64(72.25),
#   'horizontal_stripes': 1,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.7303408329143624),
#   'vertical_symmetry': np.float64(0.9578871292106587),
#   'cross_pattern': np.float64(0.42773054206059724),
#   'quarter_diversity': np.float64(0.07972350246943444)},
#  'ar': {'dominant_colors': array([[0.45482655, 0.67435897, 0.87466063],
#          [0.99991227, 0.99983989, 0.99974119],
#          [0.85605286, 0.68917306, 0.44680307],
#          [0.80619861, 0.88191018, 0.95464896],
#          [0.93660131, 0.67411765, 0.05372549],
#          [0.90735294, 0.80941176, 0.67892157],
#          [0.78655462, 0.53548086, 0.16713352],
#          [0.95367647, 0.91004902, 0.85531046]]),
#   'color_proportions': array([0.65625   , 0.26862981, 0.01382212, 0.03725962, 0.00450721,
#          0.00600962, 0.0063101 , 0.00721154]),
#   'color_categories': Counter({'orange': 4, 'white': 3, 'blue': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.7658946471216692),
#   'color_variance': np.float64(0.04342348767158403),
#   'edge_density': np.float64(0.056039663461538464),
#   'num_lines': 2,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 5,
#   'avg_shape_complexity': np.float64(1.3025616103135762),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 2,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9988188945449975),
#   'vertical_symmetry': np.float64(0.9989438002765209),
#   'cross_pattern': np.float64(0.999822350178117),
#   'quarter_diversity': np.float64(4.520882990006052e-09)},
#  'at': {'dominant_colors': array([[1.        , 1.        , 1.        ],
#          [0.92941176, 0.16078431, 0.22352941],
#          [0.97647059, 0.72156863, 0.74117647]]),
#   'color_proportions': array([0.3125 , 0.65625, 0.03125]),
#   'color_categories': Counter({'red': 2, 'white': 1}),
#   'num_colors': 3,
#   'brightness': np.float64(0.6252859477124183),
#   'color_variance': np.float64(0.14813817435334703),
#   'edge_density': np.float64(0.03125),
#   'num_lines': 2,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 4,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(1.0),
#   'vertical_symmetry': np.float64(1.0),
#   'cross_pattern': np.float64(0.9999999999999697),
#   'quarter_diversity': np.float64(4.2918963624680674e-29)},
#  'au': {'dominant_colors': array([[4.78180781e-03, 1.30172266e-01, 4.12283966e-01],
#          [9.79668917e-01, 7.96239151e-01, 8.31677917e-01],
#          [8.94117647e-01, 6.49584987e-04, 1.69150728e-01],
#          [3.26610644e-01, 4.10457516e-01, 6.01288515e-01],
#          [9.97657740e-01, 9.97421225e-01, 9.98161288e-01],
#          [9.28160200e-01, 3.22277847e-01, 4.37213183e-01],
#          [8.10215054e-01, 8.34788109e-01, 8.89247312e-01],
#          [5.65452848e-01, 6.20852786e-01, 7.43790850e-01]]),
#   'color_proportions': array([0.76794434, 0.02978516, 0.07958984, 0.02563477, 0.06274414,
#          0.01147461, 0.01513672, 0.00769043]),
#   'color_categories': Counter({'blue': 3, 'white': 3, 'red': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.29242605570874186),
#   'color_variance': np.float64(0.0935793801495274),
#   'edge_density': np.float64(0.0986328125),
#   'num_lines': 26,
#   'horizontal_lines': 14,
#   'vertical_lines': 3,
#   'diagonal_lines': 9,
#   'num_shapes': 13,
#   'avg_shape_complexity': np.float64(34.92127140571216),
#   'shape_size_variance': np.float64(1665.921875),
#   'horizontal_stripes': 2,
#   'vertical_stripes': 4,
#   'stripe_type': 'vertical',
#   'horizontal_symmetry': np.float64(0.7701609094158497),
#   'vertical_symmetry': np.float64(0.7633498646854575),
#   'cross_pattern': np.float64(0.6346496957384347),
#   'quarter_diversity': np.float64(0.041195130270076985)},
#  'az': {'dominant_colors': array([[5.21804822e-15, 7.25490196e-01, 8.94117647e-01],
#          [9.29451477e-01, 1.61315463e-01, 2.24019194e-01],
#          [2.47058824e-01, 6.11764706e-01, 2.07843137e-01],
#          [9.97540107e-01, 9.69376114e-01, 9.71657754e-01],
#          [6.19607843e-01, 3.49019608e-01, 4.47058824e-01],
#          [9.64379085e-01, 5.74101307e-01, 6.05964052e-01],
#          [7.05882353e-01, 3.05882353e-01, 2.15686275e-01],
#          [9.42034314e-01, 3.11029412e-01, 3.62254902e-01]]),
#   'color_proportions': array([0.328125  , 0.28930664, 0.328125  , 0.01342773, 0.015625  ,
#          0.00585938, 0.015625  , 0.00390625]),
#   'color_categories': Counter({'red': 4,
#            'blue': 1,
#            'green': 1,
#            'white': 1,
#            'pink': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.45381417866625834),
#   'color_variance': np.float64(0.10663133124271101),
#   'edge_density': np.float64(0.0223388671875),
#   'num_lines': 1,
#   'horizontal_lines': 1,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 3,
#   'avg_shape_complexity': np.float64(30.175896192872884),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 3,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.7671597349877451),
#   'vertical_symmetry': np.float64(0.9905889373978758),
#   'cross_pattern': np.float64(0.5076765422610675),
#   'quarter_diversity': np.float64(0.012348795219154201)},
#  'ba': {'dominant_colors': array([[4.11042604e-04, 1.37610398e-01, 5.84413709e-01],
#          [9.93627451e-01, 7.94485294e-01, 1.47058824e-03],
#          [7.96862745e-01, 8.24313725e-01, 9.16078431e-01],
#          [5.63602941e-01, 5.09129902e-01, 2.51654412e-01],
#          [9.87933635e-01, 9.89592760e-01, 9.94720965e-01],
#          [3.75000000e-01, 4.60784314e-01, 7.40196078e-01],
#          [5.98793363e-01, 6.53695324e-01, 8.33785822e-01],
#          [1.37908497e-01, 2.56862745e-01, 6.41830065e-01]]),
#   'color_proportions': array([0.68945312, 0.24609375, 0.00488281, 0.0078125 , 0.02539062,
#          0.0078125 , 0.01269531, 0.00585938]),
#   'color_categories': Counter({'blue': 4, 'orange': 2, 'white': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.36052182266135624),
#   'color_variance': np.float64(0.12540861242994036),
#   'edge_density': np.float64(0.0572509765625),
#   'num_lines': 12,
#   'horizontal_lines': 0,
#   'vertical_lines': 1,
#   'diagonal_lines': 11,
#   'num_shapes': 11,
#   'avg_shape_complexity': np.float64(118.76566918661406),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 1,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.7977101843341503),
#   'vertical_symmetry': np.float64(0.7750277650122549),
#   'cross_pattern': np.float64(0.6457539793128602),
#   'quarter_diversity': np.float64(0.003131596258451059)},
#  'bb': {'dominant_colors': array([[-1.44328993e-15,  1.49019608e-01,  4.98039216e-01],
#          [ 9.99662322e-01,  7.80133270e-01,  1.48970082e-01],
#          [ 3.72300819e-03,  2.87912633e-03,  5.46041201e-04],
#          [ 4.86710240e-01,  3.79520697e-01,  7.25490196e-02],
#          [ 6.48868778e-01,  5.06334842e-01,  9.63800905e-02],
#          [ 2.11764706e-01,  1.65032680e-01,  3.20261438e-02],
#          [ 3.54699121e-01,  2.77417174e-01,  5.34820825e-02],
#          [ 8.37611408e-01,  6.53654189e-01,  1.25133690e-01]]),
#   'color_proportions': array([0.66666667, 0.28352865, 0.02571615, 0.00292969, 0.00423177,
#          0.00390625, 0.0094401 , 0.00358073]),
#   'color_categories': Counter({'orange': 7, 'blue': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.333440138208061),
#   'color_variance': np.float64(0.10640904033296822),
#   'edge_density': np.float64(0.046549479166666664),
#   'num_lines': 4,
#   'horizontal_lines': 0,
#   'vertical_lines': 4,
#   'diagonal_lines': 0,
#   'num_shapes': 4,
#   'avg_shape_complexity': np.float64(92.56931058193705),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 2,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.977374387254902),
#   'vertical_symmetry': np.float64(0.9999463848039216),
#   'cross_pattern': np.float64(0.9941379896506617),
#   'quarter_diversity': np.float64(5.777348545613918e-06)},
#  'bd': {'dominant_colors': array([[6.15006150e-05, 4.15668910e-01, 3.05833876e-01],
#          [9.56521614e-01, 1.64794748e-01, 2.54907694e-01],
#          [3.35294118e-01, 3.27254902e-01, 2.87450980e-01],
#          [6.78823529e-01, 2.37843137e-01, 2.69607843e-01],
#          [2.16289593e-01, 3.58974359e-01, 2.95022624e-01],
#          [8.34389140e-01, 1.96983409e-01, 2.60935143e-01],
#          [5.31617647e-01, 2.75980392e-01, 2.78676471e-01],
#          [8.72549020e-02, 3.92401961e-01, 3.01715686e-01]]),
#   'color_proportions': array([0.78414352, 0.19791667, 0.00289352, 0.00289352, 0.00376157,
#          0.00376157, 0.00231481, 0.00231481]),
#   'color_categories': Counter({'red': 4, 'blue': 3, 'gray': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.2856090005446623),
#   'color_variance': np.float64(0.057214562395720425),
#   'edge_density': np.float64(0.02228009259259259),
#   'num_lines': 0,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 1,
#   'avg_shape_complexity': np.float64(1.1116863808572957),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9999345648753328),
#   'vertical_symmetry': np.float64(0.9452497125393368),
#   'cross_pattern': np.float64(0.8708844359493552),
#   'quarter_diversity': np.float64(0.0001101773688971393)},
#  'be': {'dominant_colors': array([[ 9.29411765e-01,  1.60784314e-01,  2.23529412e-01],
#          [-8.88178420e-16,  1.05471187e-15,  3.60822483e-16],
#          [ 9.80392157e-01,  8.78431373e-01,  2.58823529e-01],
#          [ 2.94117647e-01,  2.66666667e-01,  7.84313725e-02],
#          [ 9.45098039e-01,  3.80392157e-01,  2.31372549e-01],
#          [ 7.05882353e-02,  6.27450980e-02,  1.96078431e-02]]),
#   'color_proportions': array([0.32432432, 0.31081081, 0.32432432, 0.01351351, 0.01351351,
#          0.01351351]),
#   'color_categories': Counter({'orange': 3, 'red': 2, 'blue': 1}),
#   'num_colors': 6,
#   'brightness': np.float64(0.3815403638933051),
#   'color_variance': np.float64(0.1562768282793845),
#   'edge_density': np.float64(0.02702702702702703),
#   'num_lines': 2,
#   'horizontal_lines': 0,
#   'vertical_lines': 2,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 3,
#   'stripe_type': 'vertical',
#   'horizontal_symmetry': np.float64(1.0),
#   'vertical_symmetry': np.float64(0.7090620031796502),
#   'cross_pattern': np.float64(0.35513685527266103),
#   'quarter_diversity': np.float64(0.09155429869910293)},
#  'bf': {'dominant_colors': array([[6.93272639e-05, 6.19622232e-01, 2.86258813e-01],
#          [9.37268044e-01, 1.68737844e-01, 1.76456132e-01],
#          [9.80463458e-01, 8.13618538e-01, 8.83065954e-02],
#          [4.04901961e-01, 7.02941176e-01, 2.03921569e-01],
#          [9.66176471e-01, 5.49509804e-01, 1.23529412e-01],
#          [9.50588235e-01, 3.61176471e-01, 1.50784314e-01],
#          [6.56862745e-01, 7.53921569e-01, 1.53921569e-01],
#          [1.86601307e-01, 6.56535948e-01, 2.48366013e-01]]),
#   'color_proportions': array([0.48795573, 0.48567708, 0.01790365, 0.00065104, 0.00130208,
#          0.00325521, 0.00130208, 0.00195312]),
#   'color_categories': Counter({'red': 2,
#            'orange': 2,
#            'green': 2,
#            'blue': 1,
#            'yellow': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.3701820789079522),
#   'color_variance': np.float64(0.10298755310215722),
#   'edge_density': np.float64(0.011393229166666666),
#   'num_lines': 0,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 1,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.5092971303104575),
#   'vertical_symmetry': np.float64(0.9999289385893246),
#   'cross_pattern': 0.0,
#   'quarter_diversity': np.float64(0.020631691876515774)},
#  'bg': {'dominant_colors': array([[-6.88338275e-15,  5.88235294e-01,  4.31372549e-01],
#          [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 8.39215686e-01,  1.49019608e-01,  7.05882353e-02],
#          [ 3.29411765e-01,  7.25490196e-01,  6.19607843e-01],
#          [ 2.78431373e-01,  4.43137255e-01,  3.09803922e-01],
#          [ 6.05882353e-01,  4.68627451e-01,  3.80392157e-01],
#          [ 4.06722689e-01,  7.57703081e-01,  6.64519141e-01],
#          [ 4.80392157e-01,  6.45098039e-01,  5.54901961e-01]]),
#   'color_proportions': array([3.06712963e-01, 3.28125000e-01, 3.22048611e-01, 1.53356481e-02,
#          1.53356481e-02, 6.07638889e-03, 6.07638889e-03, 2.89351852e-04]),
#   'color_categories': Counter({'blue': 4,
#            'white': 1,
#            'red': 1,
#            'green': 1,
#            'orange': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5666770682038248),
#   'color_variance': np.float64(0.15099346572403782),
#   'edge_density': np.float64(0.027777777777777776),
#   'num_lines': 3,
#   'horizontal_lines': 1,
#   'vertical_lines': 2,
#   'diagonal_lines': 0,
#   'num_shapes': 1,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 4,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.570317038852578),
#   'vertical_symmetry': np.float64(0.9999512073347858),
#   'cross_pattern': np.float64(0.1582150412906813),
#   'quarter_diversity': np.float64(0.1214135138641776)},
#  'bh': {'dominant_colors': array([[0.80788742, 0.06686813, 0.14920283],
#          [1.        , 0.99994598, 0.99994598],
#          [0.88627451, 0.44247517, 0.49345556],
#          [0.9560049 , 0.78713235, 0.80625   ],
#          [0.8372549 , 0.20849673, 0.27843137],
#          [0.91605392, 0.59644608, 0.63186275],
#          [0.98470588, 0.92562092, 0.93202614],
#          [0.87081892, 0.37693195, 0.43183391]]),
#   'color_proportions': array([0.65335648, 0.31510417, 0.01114005, 0.00462963, 0.00434028,
#          0.00462963, 0.00434028, 0.00245949]),
#   'color_categories': Counter({'red': 5, 'white': 3}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5595109764584846),
#   'color_variance': np.float64(0.16636334136988074),
#   'edge_density': np.float64(0.03139467592592592),
#   'num_lines': 1,
#   'horizontal_lines': 0,
#   'vertical_lines': 1,
#   'diagonal_lines': 0,
#   'num_shapes': 6,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 1,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9992862654320988),
#   'vertical_symmetry': np.float64(0.5732075314693779),
#   'cross_pattern': np.float64(0.17236757671494818),
#   'quarter_diversity': np.float64(0.069147198530153)},
#  'bi': {'dominant_colors': array([[ 1.19447506e-01,  7.10203093e-01,  2.28865618e-01],
#          [ 9.98809018e-01,  9.98610816e-01,  9.98152474e-01],
#          [ 8.07981410e-01,  6.97989284e-02,  1.51552688e-01],
#          [-1.11022302e-16,  3.33066907e-16, -1.11022302e-16],
#          [ 8.82414216e-01,  4.28676471e-01,  4.78308824e-01],
#          [ 4.78701826e-01,  8.07212080e-01,  5.28194726e-01],
#          [ 8.52819473e-01,  8.62285328e-01,  8.00784314e-01],
#          [ 5.19261822e-01,  4.02306805e-01,  2.34832757e-01]]),
#   'color_proportions': array([0.32756696, 0.30915179, 0.28487723, 0.03236607, 0.00892857,
#          0.01213728, 0.02022879, 0.0047433 ]),
#   'color_categories': Counter({'green': 3, 'white': 2, 'red': 2, 'orange': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5534762342436975),
#   'color_variance': np.float64(0.15256431512563987),
#   'edge_density': np.float64(0.09877232142857142),
#   'num_lines': 13,
#   'horizontal_lines': 0,
#   'vertical_lines': 2,
#   'diagonal_lines': 11,
#   'num_shapes': 11,
#   'avg_shape_complexity': np.float64(26.311922579986287),
#   'shape_size_variance': np.float64(277299.1020408163),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 2,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9811019199346406),
#   'vertical_symmetry': np.float64(0.9988233835200747),
#   'cross_pattern': np.float64(0.988790942301046),
#   'quarter_diversity': np.float64(2.730541713752776e-05)},
#  'bj': {'dominant_colors': array([[ 9.88235294e-01,  8.19607843e-01,  8.62745098e-02],
#          [-1.99840144e-15,  5.29411765e-01,  3.17647059e-01],
#          [ 9.09803922e-01,  6.66666667e-02,  1.76470588e-01],
#          [ 5.45098039e-01,  2.50980392e-01,  2.31372549e-01],
#          [ 5.92156863e-01,  7.01960784e-01,  1.76470588e-01]]),
#   'color_proportions': array([0.296875  , 0.39583333, 0.296875  , 0.00520833, 0.00520833]),
#   'color_categories': Counter({'red': 2, 'orange': 1, 'blue': 1, 'yellow': 1}),
#   'num_colors': 5,
#   'brightness': np.float64(0.41763344226579513),
#   'color_variance': np.float64(0.1274026547763562),
#   'edge_density': np.float64(0.014485677083333334),
#   'num_lines': 2,
#   'horizontal_lines': 1,
#   'vertical_lines': 1,
#   'diagonal_lines': 0,
#   'num_shapes': 1,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 1,
#   'vertical_stripes': 2,
#   'stripe_type': 'both',
#   'horizontal_symmetry': np.float64(0.8156862745098039),
#   'vertical_symmetry': np.float64(0.5968681917211329),
#   'cross_pattern': np.float64(0.09865642926572327),
#   'quarter_diversity': np.float64(0.078444545201006)},
#  'bn': {'dominant_colors': array([[0.96809671, 0.87770406, 0.09169984],
#          [0.00550831, 0.00237866, 0.00172993],
#          [0.99902497, 0.99784493, 0.99650992],
#          [0.81811531, 0.42347088, 0.11226222],
#          [0.93398153, 0.82433965, 0.67642197],
#          [0.37213349, 0.14205947, 0.10422023],
#          [0.74994233, 0.48235294, 0.50588235],
#          [0.7959095 , 0.10572549, 0.15967421]]),
#   'color_proportions': array([0.5357666 , 0.16381836, 0.20080566, 0.01635742, 0.01477051,
#          0.01843262, 0.01037598, 0.03967285]),
#   'color_categories': Counter({'red': 4, 'orange': 3, 'white': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5901194852941176),
#   'color_variance': np.float64(0.18727696793363233),
#   'edge_density': np.float64(0.08203125),
#   'num_lines': 12,
#   'horizontal_lines': 8,
#   'vertical_lines': 1,
#   'diagonal_lines': 3,
#   'num_shapes': 10,
#   'avg_shape_complexity': np.float64(118.66174611016066),
#   'shape_size_variance': np.float64(1910.8888888888887),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.7062021292892158),
#   'vertical_symmetry': np.float64(0.6911726409313725),
#   'cross_pattern': np.float64(0.6476508261880931),
#   'quarter_diversity': np.float64(0.032266631039150784)},
#  'bo': {'dominant_colors': array([[8.24757416e-01, 1.27348487e-01, 6.70210830e-02],
#          [5.78785731e-04, 4.38107331e-01, 1.76277660e-01],
#          [9.40242154e-01, 8.97220089e-01, 2.36553525e-01],
#          [7.89428815e-01, 7.88765748e-01, 2.34991001e-01],
#          [4.12599082e-01, 4.77513559e-01, 2.43721318e-01],
#          [8.64052288e-01, 5.57327524e-01, 1.61975309e-01],
#          [2.58505564e-01, 5.32591415e-01, 5.19236884e-01],
#          [8.01031992e-01, 8.33849329e-01, 6.15067079e-01]]),
#   'color_proportions': array([0.34025931, 0.33111702, 0.25465426, 0.03440824, 0.0078125 ,
#          0.02244016, 0.00615027, 0.00315824]),
#   'color_categories': Counter({'yellow': 4, 'blue': 2, 'red': 1, 'orange': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.400163833263802),
#   'color_variance': np.float64(0.11989177179857374),
#   'edge_density': np.float64(0.05701462765957447),
#   'num_lines': 2,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 5,
#   'avg_shape_complexity': np.float64(12.430836885517532),
#   'shape_size_variance': np.float64(351.5625),
#   'horizontal_stripes': 3,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.709358920873314),
#   'vertical_symmetry': np.float64(0.996989292170769),
#   'cross_pattern': np.float64(0.4076627941647921),
#   'quarter_diversity': np.float64(0.016961043104407776)},
#  'br': {'dominant_colors': array([[6.39900405e-04, 6.08016184e-01, 2.27306567e-01],
#          [9.90628604e-01, 8.72396606e-01, 1.63124073e-03],
#          [6.20966988e-03, 1.57748059e-01, 4.62851086e-01],
#          [4.73262032e-01, 5.82798574e-01, 6.96524064e-01],
#          [7.08823529e-01, 7.71132898e-01, 8.75272331e-02],
#          [7.01338313e-01, 8.50482415e-01, 7.82259570e-01],
#          [3.59225742e-01, 6.29813977e-01, 1.84213172e-01],
#          [2.16775599e-01, 3.28685548e-01, 5.18881627e-01]]),
#   'color_proportions': array([0.76904297, 0.11621094, 0.07678223, 0.00537109, 0.00878906,
#          0.00769043, 0.00952148, 0.0065918 ]),
#   'color_categories': Counter({'blue': 3,
#            'green': 2,
#            'orange': 1,
#            'yellow': 1,
#            'white': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.32234652650122547),
#   'color_variance': np.float64(0.09052827736918288),
#   'edge_density': np.float64(0.0604248046875),
#   'num_lines': 8,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 8,
#   'num_shapes': 1,
#   'avg_shape_complexity': np.float64(1.5040396551483137),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9871479907066993),
#   'vertical_symmetry': np.float64(0.9875788271037582),
#   'cross_pattern': np.float64(0.9904025658209419),
#   'quarter_diversity': np.float64(2.6637942936547534e-05)},
#  'bs': {'dominant_colors': array([[-9.15933995e-16,  4.66405229e-01,  5.44791320e-01],
#          [ 9.99649251e-01,  7.80119352e-01,  1.72490561e-01],
#          [ 1.72476398e-04,  4.42538126e-04,  3.97149601e-04],
#          [ 6.66623094e-01,  6.78387800e-01,  2.94117647e-01],
#          [ 0.00000000e+00,  2.68907563e-01,  3.14005602e-01],
#          [ 4.00490196e-01,  3.25490196e-01,  8.30882353e-02],
#          [ 7.65490196e-01,  5.98039216e-01,  1.31372549e-01],
#          [ 3.81699346e-02,  1.17516340e-01,  1.09150327e-01]]),
#   'color_proportions': array([0.56030273, 0.1965332 , 0.2109375 , 0.02197266, 0.00341797,
#          0.00195312, 0.0012207 , 0.00366211]),
#   'color_categories': Counter({'blue': 4, 'orange': 3, 'yellow': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.33095224417892155),
#   'color_variance': np.float64(0.10191573684465786),
#   'edge_density': np.float64(0.042236328125),
#   'num_lines': 5,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 3,
#   'num_shapes': 3,
#   'avg_shape_complexity': np.float64(90.29225603362957),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 2,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9999782986111111),
#   'vertical_symmetry': np.float64(0.7782443576388889),
#   'cross_pattern': np.float64(0.604179156510924),
#   'quarter_diversity': np.float64(0.034572780740022534)},
#  'bt': {'dominant_colors': array([[0.99913812, 0.83367586, 0.12664928],
#          [0.9987576 , 0.30797029, 0.07235545],
#          [0.90341485, 0.89441507, 0.8843688 ],
#          [0.90458864, 0.63408126, 0.54141904],
#          [0.96575836, 0.96379758, 0.96235582],
#          [0.89354036, 0.81285956, 0.71752762],
#          [0.91825708, 0.82313725, 0.43769063],
#          [0.92282135, 0.46683007, 0.30953159]]),
#   'color_proportions': array([0.42952474, 0.39404297, 0.05794271, 0.01578776, 0.04427083,
#          0.0320638 , 0.01464844, 0.01171875]),
#   'color_categories': Counter({'red': 3, 'white': 3, 'orange': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.610296670751634),
#   'color_variance': np.float64(0.14623507768128335),
#   'edge_density': np.float64(0.08154296875),
#   'num_lines': 15,
#   'horizontal_lines': 1,
#   'vertical_lines': 1,
#   'diagonal_lines': 13,
#   'num_shapes': 11,
#   'avg_shape_complexity': np.float64(102.86530300193998),
#   'shape_size_variance': np.float64(122.7),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.8454844090413943),
#   'vertical_symmetry': np.float64(0.8443882761437909),
#   'cross_pattern': np.float64(0.7280865591150059),
#   'quarter_diversity': np.float64(0.007469885134555631)},
#  'bw': {'dominant_colors': array([[ 4.27450980e-01,  6.62745098e-01,  8.23529412e-01],
#          [-2.05391260e-15,  9.99200722e-16,  2.88657986e-15],
#          [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 6.66666667e-01,  6.66666667e-01,  6.66666667e-01]]),
#   'color_proportions': array([0.75   , 0.15625, 0.0625 , 0.03125]),
#   'color_categories': Counter({'blue': 2, 'white': 1, 'gray': 1}),
#   'num_colors': 4,
#   'brightness': np.float64(0.561764705882353),
#   'color_variance': np.float64(0.08584582852748943),
#   'edge_density': np.float64(0.0625),
#   'num_lines': 4,
#   'horizontal_lines': 4,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 4,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 6,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(1.0),
#   'vertical_symmetry': np.float64(1.0),
#   'cross_pattern': np.float64(0.9999999999999929),
#   'quarter_diversity': np.float64(8.985618748533088e-30)},
#  'by': {'dominant_colors': array([[ 8.23595866e-01,  1.53434500e-01,  1.88694218e-01],
#          [-8.43769499e-15,  5.92156863e-01,  2.23529412e-01],
#          [ 9.61568627e-01,  8.24546115e-01,  8.31401598e-01],
#          [ 8.79935536e-01,  4.29062584e-01,  4.52323395e-01],
#          [ 5.49019608e-01,  2.98039216e-01,  2.00000000e-01],
#          [ 9.92234775e-01,  9.68965069e-01,  9.70081808e-01],
#          [ 9.18512111e-01,  6.26960784e-01,  6.41407151e-01],
#          [ 8.50594664e-01,  2.83381549e-01,  3.12729026e-01]]),
#   'color_proportions': array([0.61230469, 0.28967285, 0.01647949, 0.01782227, 0.01379395,
#          0.01843262, 0.01660156, 0.01489258]),
#   'color_categories': Counter({'red': 5, 'white': 2, 'green': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.38363731234681375),
#   'color_variance': np.float64(0.0948303360853014),
#   'edge_density': np.float64(0.0552978515625),
#   'num_lines': 15,
#   'horizontal_lines': 0,
#   'vertical_lines': 15,
#   'diagonal_lines': 0,
#   'num_shapes': 19,
#   'avg_shape_complexity': np.float64(5.927215984094072),
#   'shape_size_variance': np.float64(4252.472222222222),
#   'horizontal_stripes': 1,
#   'vertical_stripes': 2,
#   'stripe_type': 'both',
#   'horizontal_symmetry': np.float64(0.7451819725285949),
#   'vertical_symmetry': np.float64(0.9206172768586601),
#   'cross_pattern': np.float64(0.4386941374699358),
#   'quarter_diversity': np.float64(0.019217528742603896)},
#  'bz': {'dominant_colors': array([[0.09084016, 0.08795211, 0.58887563],
#          [0.85090777, 0.05882353, 0.09796659],
#          [0.76244984, 0.79715346, 0.67331365],
#          [0.57919486, 0.64615652, 0.42597605],
#          [0.3965998 , 0.08786127, 0.37513317],
#          [0.94805732, 0.9557556 , 0.94658803],
#          [0.57533664, 0.59225136, 0.79262934],
#          [0.31480831, 0.57971905, 0.15604331]]),
#   'color_proportions': array([0.60604745, 0.1875    , 0.03747106, 0.03269676, 0.05005787,
#          0.05483218, 0.0120081 , 0.01938657]),
#   'color_categories': Counter({'purple': 2,
#            'red': 1,
#            'gray': 1,
#            'yellow': 1,
#            'pink': 1,
#            'white': 1,
#            'green': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.34502598493100944),
#   'color_variance': np.float64(0.09531208912968983),
#   'edge_density': np.float64(0.11328125),
#   'num_lines': 7,
#   'horizontal_lines': 2,
#   'vertical_lines': 3,
#   'diagonal_lines': 2,
#   'num_shapes': 1,
#   'avg_shape_complexity': np.float64(1.476799161307525),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 4,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.9663084755507141),
#   'vertical_symmetry': np.float64(0.9800596859114016),
#   'cross_pattern': np.float64(0.9858313434280789),
#   'quarter_diversity': np.float64(5.610710431687122e-05)},
#  'ca': {'dominant_colors': array([[0.83532015, 0.1687668 , 0.11779789],
#          [0.99995361, 0.99977076, 0.99974075],
#          [0.91654902, 0.57945098, 0.55403922],
#          [0.97499075, 0.87325194, 0.86474288],
#          [0.87755991, 0.38242556, 0.34364561],
#          [0.9469281 , 0.73333333, 0.71764706],
#          [0.89615105, 0.47494553, 0.44270153],
#          [0.85732411, 0.27820069, 0.23391003]]),
#   'color_proportions': array([0.62524414, 0.35083008, 0.00305176, 0.00646973, 0.0032959 ,
#          0.00366211, 0.0032959 , 0.00415039]),
#   'color_categories': Counter({'red': 6, 'white': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.6010971966911763),
#   'color_variance': np.float64(0.1565382418754115),
#   'edge_density': np.float64(0.0433349609375),
#   'num_lines': 3,
#   'horizontal_lines': 0,
#   'vertical_lines': 2,
#   'diagonal_lines': 1,
#   'num_shapes': 4,
#   'avg_shape_complexity': np.float64(2.5215872786433935),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 2,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.965753293504902),
#   'vertical_symmetry': np.float64(0.999853196486928),
#   'cross_pattern': np.float64(0.9881478883990954),
#   'quarter_diversity': np.float64(1.6550769025885248e-05)},
#  'cd': {'dominant_colors': array([[5.81704834e-04, 4.98317995e-01, 9.99472075e-01],
#          [8.28090367e-01, 2.52514919e-01, 1.41602728e-01],
#          [9.63608132e-01, 8.29985917e-01, 9.72664572e-02],
#          [4.92615770e-01, 6.69920734e-01, 5.39257405e-01],
#          [8.08111954e-01, 6.36582859e-02, 1.29411765e-01],
#          [2.09704892e-01, 5.73341256e-01, 8.03842345e-01],
#          [9.03402537e-01, 5.34256055e-01, 1.09515571e-01],
#          [7.50718954e-01, 7.61307190e-01, 2.97690632e-01]]),
#   'color_proportions': array([0.64916424, 0.01671512, 0.09865552, 0.00853924, 0.18023256,
#          0.01798692, 0.01235465, 0.01635174]),
#   'color_categories': Counter({'blue': 2,
#            'red': 2,
#            'orange': 2,
#            'green': 1,
#            'yellow': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.4839634157926736),
#   'color_variance': np.float64(0.1543858152348279),
#   'edge_density': np.float64(0.10919331395348837),
#   'num_lines': 7,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 7,
#   'num_shapes': 8,
#   'avg_shape_complexity': np.float64(130.3131443569588),
#   'shape_size_variance': np.float64(66.25),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.6776120041039672),
#   'vertical_symmetry': np.float64(0.6776272039823681),
#   'cross_pattern': np.float64(0.9101255895455208),
#   'quarter_diversity': np.float64(0.014859954706102012)},
#  'cf': {'dominant_colors': array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#          [1.56862745e-01, 5.92156863e-01, 1.56862745e-01],
#          [9.99735190e-01, 8.07679491e-01, 1.39843494e-04],
#          [8.23529412e-01, 6.27450980e-02, 2.03921569e-01],
#          [4.82053286e-04, 1.88528435e-01, 5.09553124e-01],
#          [5.51633987e-01, 5.29673203e-01, 2.29281046e-01],
#          [2.74208145e-01, 3.58974359e-01, 3.69834087e-01],
#          [8.00392157e-01, 6.84313725e-01, 1.01568627e-01]]),
#   'color_proportions': array([0.20833333, 0.20833333, 0.21451823, 0.16666667, 0.19596354,
#          0.00244141, 0.00211589, 0.0016276 ]),
#   'color_categories': Counter({'orange': 2,
#            'blue': 2,
#            'white': 1,
#            'green': 1,
#            'red': 1,
#            'yellow': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5093250017020697),
#   'color_variance': np.float64(0.15567130638990515),
#   'edge_density': np.float64(0.06266276041666667),
#   'num_lines': 8,
#   'horizontal_lines': 6,
#   'vertical_lines': 2,
#   'diagonal_lines': 0,
#   'num_shapes': 3,
#   'avg_shape_complexity': np.float64(146.01215263941245),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 3,
#   'vertical_stripes': 2,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.42681653390522867),
#   'vertical_symmetry': np.float64(0.9865821589052287),
#   'cross_pattern': np.float64(0.438344888352726),
#   'quarter_diversity': np.float64(0.005517320855587913)},
#  'cg': {'dominant_colors': array([[8.62745098e-01, 1.41176471e-01, 1.21568627e-01],
#          [2.88657986e-15, 5.84313725e-01, 2.62745098e-01],
#          [9.84313725e-01, 8.70588235e-01, 2.90196078e-01],
#          [4.94117647e-01, 7.25490196e-01, 2.74509804e-01],
#          [9.21568627e-01, 5.05882353e-01, 2.07843137e-01]]),
#   'color_proportions': array([0.328125  , 0.328125  , 0.32291667, 0.01041667, 0.01041667]),
#   'color_categories': Counter({'orange': 2, 'red': 1, 'blue': 1, 'green': 1}),
#   'num_colors': 5,
#   'brightness': np.float64(0.4575095315904139),
#   'color_variance': np.float64(0.12264589291504395),
#   'edge_density': np.float64(0.031087239583333332),
#   'num_lines': 4,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 4,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.7674428104575164),
#   'vertical_symmetry': np.float64(0.6476239106753813),
#   'cross_pattern': np.float64(0.42831580321374785),
#   'quarter_diversity': np.float64(0.02358450783048678)},
#  'ch': {'dominant_colors': array([[0.85490196, 0.16078431, 0.10980392],
#          [1.        , 1.        , 1.        ]]),
#   'color_proportions': array([0.80078125, 0.19921875]),
#   'color_categories': Counter({'red': 1, 'white': 1}),
#   'num_colors': 2,
#   'brightness': np.float64(0.49964256535947715),
#   'color_variance': np.float64(0.15478048546616016),
#   'edge_density': np.float64(0.0361328125),
#   'num_lines': 4,
#   'horizontal_lines': 2,
#   'vertical_lines': 2,
#   'diagonal_lines': 0,
#   'num_shapes': 1,
#   'avg_shape_complexity': np.float64(2.2715156884044734),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 2,
#   'vertical_stripes': 2,
#   'stripe_type': 'both',
#   'horizontal_symmetry': np.float64(1.0),
#   'vertical_symmetry': np.float64(1.0),
#   'cross_pattern': np.float64(0.9999999999999878),
#   'quarter_diversity': np.float64(1.6211707899873997e-29)},
#  'ci': {'dominant_colors': array([[3.33066907e-16, 6.19607843e-01, 3.76470588e-01],
#          [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#          [9.68627451e-01, 4.98039216e-01, 5.55111512e-16]]),
#   'color_proportions': array([0.33333333, 0.33333333, 0.33333333]),
#   'color_categories': Counter({'blue': 1, 'white': 1, 'orange': 1}),
#   'num_colors': 3,
#   'brightness': np.float64(0.6069716775599129),
#   'color_variance': np.float64(0.15513273622206084),
#   'edge_density': np.float64(0.020833333333333332),
#   'num_lines': 2,
#   'horizontal_lines': 0,
#   'vertical_lines': 2,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 2,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(1.0),
#   'vertical_symmetry': np.float64(0.674074074074074),
#   'cross_pattern': np.float64(0.30246523821251114),
#   'quarter_diversity': np.float64(0.012655119731080888)},
#  'cl': {'dominant_colors': array([[8.35294118e-01, 1.68627451e-01, 1.17647059e-01],
#          [9.99928971e-01, 9.99945793e-01, 9.99975700e-01],
#          [1.19093190e-04, 2.23622985e-01, 6.51022925e-01],
#          [4.50749712e-01, 5.72549020e-01, 8.08996540e-01],
#          [1.48529412e-01, 3.38480392e-01, 7.02941176e-01],
#          [7.80392157e-01, 8.29803922e-01, 9.23921569e-01],
#          [5.90686275e-01, 6.82352941e-01, 8.57352941e-01],
#          [8.83660131e-01, 9.10457516e-01, 9.59477124e-01]]),
#   'color_proportions': array([0.5       , 0.34147135, 0.1500651 , 0.00276693, 0.00260417,
#          0.0008138 , 0.00130208, 0.00097656]),
#   'color_categories': Counter({'blue': 4, 'white': 3, 'red': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5773709831154684),
#   'color_variance': np.float64(0.158842781430437),
#   'edge_density': np.float64(0.028645833333333332),
#   'num_lines': 2,
#   'horizontal_lines': 1,
#   'vertical_lines': 1,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': np.float64(347.567900486972),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 1,
#   'vertical_stripes': 1,
#   'stripe_type': 'both',
#   'horizontal_symmetry': np.float64(0.42157543572984735),
#   'vertical_symmetry': np.float64(0.78088575708061),
#   'cross_pattern': 0.0,
#   'quarter_diversity': np.float64(0.13013224705451465)},
#  'cm': {'dominant_colors': array([[ 9.88190646e-01,  8.19431112e-01,  8.62931131e-02],
#          [-9.99200722e-16,  4.78431373e-01,  3.68627451e-01],
#          [ 8.07861330e-01,  6.67434809e-02,  1.49011522e-01],
#          [ 9.23774510e-01,  5.52696078e-01,  1.09558824e-01],
#          [ 8.58823529e-01,  2.82745098e-01,  1.30980392e-01],
#          [ 9.48627451e-01,  6.52156863e-01,  1.00000000e-01],
# ...
#          0.015625  , 0.00634766, 0.00427246]),
#   'color_categories': Counter({'blue': 3,
#            'green': 1,
#            'white': 1,
#            'red': 1,
#            'pink': 1,
#            'orange': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.5919393701491014),
#   'color_variance': np.float64(0.13190493728322758),
#   'edge_density': np.float64(0.045654296875),
#   'num_lines': 2,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 18,
#   'avg_shape_complexity': np.float64(5.602110949307305),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 6,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.8429569418913399),
#   'vertical_symmetry': np.float64(0.9889562270220589),
#   'cross_pattern': np.float64(0.6739373790266826),
#   'quarter_diversity': np.float64(0.0037870302437915)},
#  'va': {'dominant_colors': array([[ 7.25743201e-01,  6.02087287e-01,  4.22011385e-01],
#          [ 9.99427456e-01,  9.99381940e-01,  9.99290908e-01],
#          [ 1.00000000e+00,  8.78431373e-01, -2.22044605e-15],
#          [ 8.14174837e-01,  7.85498366e-01,  7.41911765e-01],
#          [ 7.00784314e-01,  5.65322129e-01,  1.61904762e-01],
#          [ 9.03132747e-01,  8.89474870e-01,  8.72526482e-01],
#          [ 7.60308972e-01,  6.97147950e-01,  6.07783720e-01],
#          [ 7.20261438e-01,  3.13333333e-01,  2.69934641e-01]]),
#   'color_proportions': array([0.01513672, 0.3996582 , 0.5       , 0.02294922, 0.01708984,
#          0.02124023, 0.01660156, 0.00732422]),
#   'color_categories': Counter({'orange': 4, 'white': 3, 'red': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.7808788424223856),
#   'color_variance': np.float64(0.1355701354599105),
#   'edge_density': np.float64(0.074462890625),
#   'num_lines': 3,
#   'horizontal_lines': 0,
#   'vertical_lines': 3,
#   'diagonal_lines': 0,
#   'num_shapes': 3,
#   'avg_shape_complexity': np.float64(14.53276086254375),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 1,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9707841860702614),
#   'vertical_symmetry': np.float64(0.6361500459558824),
#   'cross_pattern': np.float64(0.08452717335072402),
#   'quarter_diversity': np.float64(0.02110048517264438)},
#  'vc': {'dominant_colors': array([[ 9.87943069e-01,  8.15572716e-01,  1.33343932e-01],
#          [ 3.85899040e-04,  4.86408010e-01,  1.80371297e-01],
#          [-6.10622664e-16,  1.49019608e-01,  4.54901961e-01],
#          [ 5.25311943e-01,  6.61319073e-01,  1.56149733e-01],
#          [ 6.80532213e-01,  7.12605042e-01,  1.48459384e-01],
#          [ 1.50567595e-01,  5.36119711e-01,  1.73065015e-01],
#          [ 8.74929972e-01,  7.77591036e-01,  1.38515406e-01],
#          [ 3.51693405e-01,  6.02673797e-01,  1.63636364e-01]]),
#   'color_proportions': array([0.42154948, 0.30598958, 0.25      , 0.00358073, 0.00455729,
#          0.0061849 , 0.00455729, 0.00358073]),
#   'color_categories': Counter({'green': 3,
#            'orange': 2,
#            'yellow': 2,
#            'blue': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.400308287377451),
#   'color_variance': np.float64(0.12524557285772456),
#   'edge_density': np.float64(0.051106770833333336),
#   'num_lines': 4,
#   'horizontal_lines': 0,
#   'vertical_lines': 2,
#   'diagonal_lines': 2,
#   'num_shapes': 5,
#   'avg_shape_complexity': np.float64(1.4913046127234368),
#   'shape_size_variance': np.float64(0.8888888888888888),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 2,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9796011199618736),
#   'vertical_symmetry': np.float64(0.8979341128812636),
#   'cross_pattern': np.float64(0.7779920041274139),
#   'quarter_diversity': np.float64(0.0020055777306565306)},
#  've': {'dominant_colors': array([[1.05228758e-03, 1.42082789e-01, 4.90740741e-01],
#          [1.00000000e+00, 8.00000000e-01, 2.74780199e-15],
#          [8.11764706e-01, 7.84313725e-02, 1.68627451e-01],
#          [5.96078431e-01, 6.52941176e-01, 7.93363499e-01],
#          [3.33333333e-01, 3.60784314e-01, 3.25490196e-01],
#          [9.48549020e-01, 9.55843137e-01, 9.73176471e-01],
#          [2.95811052e-01, 3.95454545e-01, 6.40819964e-01],
#          [2.66666667e-01, 1.21568627e-01, 3.84313725e-01]]),
#   'color_proportions': array([0.29296875, 0.328125  , 0.328125  , 0.00423177, 0.015625  ,
#          0.00813802, 0.00716146, 0.015625  ]),
#   'color_categories': Counter({'blue': 3,
#            'orange': 1,
#            'red': 1,
#            'gray': 1,
#            'white': 1,
#            'purple': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.3977866710920479),
#   'color_variance': np.float64(0.13664883795239968),
#   'edge_density': np.float64(0.044596354166666664),
#   'num_lines': 2,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 10,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 3,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.7430330031318082),
#   'vertical_symmetry': np.float64(0.9999051096132897),
#   'cross_pattern': np.float64(0.48646120571711804),
#   'quarter_diversity': np.float64(0.021109242193057154)},
#  'vn': {'dominant_colors': array([[8.54912620e-01, 1.45164025e-01, 1.13716861e-01],
#          [9.99667135e-01, 9.97659541e-01, 2.91257086e-04],
#          [9.26797386e-01, 5.64705882e-01, 5.81699346e-02],
#          [9.66666667e-01, 8.02832244e-01, 2.61437908e-02],
#          [8.76797386e-01, 2.75000000e-01, 9.64052288e-02],
#          [9.09150327e-01, 4.64923747e-01, 7.16775599e-02],
#          [9.86143791e-01, 9.14771242e-01, 1.15032680e-02],
#          [9.48039216e-01, 6.92647059e-01, 4.01960784e-02]]),
#   'color_proportions': array([9.43115234e-01, 4.60205078e-02, 7.32421875e-04, 2.19726562e-03,
#          2.92968750e-03, 2.19726562e-03, 1.83105469e-03, 9.76562500e-04]),
#   'color_categories': Counter({'orange': 4, 'red': 2, 'yellow': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.38647476894403593),
#   'color_variance': np.float64(0.1262971535337399),
#   'edge_density': np.float64(0.017333984375),
#   'num_lines': 3,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 3,
#   'num_shapes': 3,
#   'avg_shape_complexity': np.float64(3.3542509846945623),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9826041028390523),
#   'vertical_symmetry': np.float64(0.9999122370302288),
#   'cross_pattern': np.float64(0.9918317264754802),
#   'quarter_diversity': np.float64(2.0984112662365734e-06)},
#  'vu': {'dominant_colors': array([[8.22352018e-01, 6.26066897e-02, 2.03666897e-01],
#          [1.44328993e-15, 5.83398385e-01, 2.62407382e-01],
#          [3.07311592e-03, 2.53525750e-03, 5.15132003e-04],
#          [9.78160920e-01, 7.96499136e-01, 6.96266246e-02],
#          [6.73093202e-01, 5.46739224e-01, 4.87345599e-02],
#          [3.51143791e-01, 2.85757081e-01, 3.43409586e-02],
#          [2.39431836e-01, 5.48710823e-02, 4.98996449e-02],
#          [2.22044605e-16, 1.88719982e-01, 8.49085702e-02]]),
#   'color_proportions': array([0.30743634, 0.30743634, 0.22468171, 0.07552083, 0.03284144,
#          0.02083333, 0.01837384, 0.01287616]),
#   'color_categories': Counter({'orange': 4, 'red': 2, 'blue': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.26695526204308884),
#   'color_variance': np.float64(0.09542583017903931),
#   'edge_density': np.float64(0.12254050925925926),
#   'num_lines': 13,
#   'horizontal_lines': 4,
#   'vertical_lines': 1,
#   'diagonal_lines': 8,
#   'num_shapes': 4,
#   'avg_shape_complexity': np.float64(40.807296316574245),
#   'shape_size_variance': np.float64(252879.0555555556),
#   'horizontal_stripes': 3,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.698064179375454),
#   'vertical_symmetry': np.float64(0.8246217622851609),
#   'cross_pattern': np.float64(0.37930570768158944),
#   'quarter_diversity': np.float64(0.01419825907716088)},
#  'ws': {'dominant_colors': array([[8.07843137e-01, 6.66666667e-02, 1.49019608e-01],
#          [8.06651775e-05, 1.68695706e-01, 4.98074377e-01],
#          [5.40989729e-01, 6.18487395e-01, 7.69747899e-01],
#          [9.76358543e-01, 9.80616246e-01, 9.87675070e-01],
#          [1.90080738e-01, 3.26412918e-01, 5.94002307e-01],
#          [7.50588235e-01, 7.92470588e-01, 8.74352941e-01],
#          [4.07843137e-01, 5.07390649e-01, 7.02865762e-01],
#          [6.34146341e-02, 2.21138211e-01, 5.30846485e-01]]),
#   'color_proportions': array([0.75      , 0.23144531, 0.00256348, 0.00427246, 0.0020752 ,
#          0.00305176, 0.00158691, 0.00500488]),
#   'color_categories': Counter({'blue': 5, 'white': 2, 'red': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.3186145258884804),
#   'color_variance': np.float64(0.09822919246868707),
#   'edge_density': np.float64(0.015380859375),
#   'num_lines': 2,
#   'horizontal_lines': 1,
#   'vertical_lines': 1,
#   'diagonal_lines': 0,
#   'num_shapes': 9,
#   'avg_shape_complexity': np.float64(1.340333422152547),
#   'shape_size_variance': np.float64(1.5625),
#   'horizontal_stripes': 1,
#   'vertical_stripes': 1,
#   'stripe_type': 'both',
#   'horizontal_symmetry': np.float64(0.7871569265727124),
#   'vertical_symmetry': np.float64(0.7871569265727124),
#   'cross_pattern': np.float64(0.5678448658329914),
#   'quarter_diversity': np.float64(0.013593573407582707)},
#  'xk': {'dominant_colors': array([[0.14173896, 0.29046743, 0.64697813],
#          [0.81407779, 0.65009074, 0.31455108],
#          [0.70831643, 0.7597025 , 0.88018932],
#          [0.39808093, 0.42753442, 0.52031706],
#          [0.96174863, 0.96817743, 0.98412086],
#          [0.32872975, 0.44492754, 0.72412617],
#          [0.64386685, 0.55905153, 0.39826721],
#          [0.50165913, 0.58853695, 0.79562594]]),
#   'color_proportions': array([0.86059028, 0.09565972, 0.00503472, 0.00815972, 0.01059028,
#          0.00798611, 0.00746528, 0.00451389]),
#   'color_categories': Counter({'blue': 4, 'orange': 2, 'white': 2}),
#   'num_colors': 8,
#   'brightness': np.float64(0.3949934186637618),
#   'color_variance': np.float64(0.05292055067969853),
#   'edge_density': np.float64(0.03888888888888889),
#   'num_lines': 1,
#   'horizontal_lines': 0,
#   'vertical_lines': 0,
#   'diagonal_lines': 1,
#   'num_shapes': 9,
#   'avg_shape_complexity': np.float64(1.4045553509609607),
#   'shape_size_variance': np.float64(80936.05555555558),
#   'horizontal_stripes': 0,
#   'vertical_stripes': 0,
#   'stripe_type': 'none',
#   'horizontal_symmetry': np.float64(0.9323216230936819),
#   'vertical_symmetry': np.float64(0.9820937726942629),
#   'cross_pattern': np.float64(0.9348661113574562),
#   'quarter_diversity': np.float64(0.00010580340956509988)},
#  'ye': {'dominant_colors': array([[0.80784314, 0.06666667, 0.14901961],
#          [1.        , 1.        , 1.        ],
#          [0.9372549 , 0.69019608, 0.71764706],
#          [0.67058824, 0.67058824, 0.67058824]]),
#   'color_proportions': array([0.48837209, 0.46511628, 0.02325581, 0.02325581]),
#   'color_categories': Counter({'red': 2, 'white': 1, 'gray': 1}),
#   'num_colors': 4,
#   'brightness': np.float64(0.6655114759081926),
#   'color_variance': np.float64(0.15774097692915373),
#   'edge_density': np.float64(0.046511627906976744),
#   'num_lines': 2,
#   'horizontal_lines': 2,
#   'vertical_lines': 0,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': 0,
#   'shape_size_variance': 0,
#   'horizontal_stripes': 3,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.3525054466230936),
#   'vertical_symmetry': np.float64(1.0),
#   'cross_pattern': 0.0,
#   'quarter_diversity': np.float64(0.18696052903587368)},
#  'za': {'dominant_colors': array([[8.78658799e-01, 2.36707849e-01, 1.93638208e-01],
#          [1.98870348e-03, 4.67448403e-01, 2.86676116e-01],
#          [9.94879989e-01, 9.94513799e-01, 9.93814708e-01],
#          [1.81633782e-03, 8.01124839e-02, 5.38112361e-01],
#          [6.81571522e-03, 4.94899067e-03, 7.23536647e-04],
#          [9.57562594e-01, 7.04156863e-01, 1.13073906e-01],
#          [7.02174091e-01, 7.49265731e-01, 7.50381492e-01],
#          [3.61668048e-01, 5.25379729e-01, 2.80364540e-01]]),
#   'color_proportions': array([0.20768229, 0.29720052, 0.09586589, 0.20768229, 0.08821615,
#          0.05289714, 0.03889974, 0.01155599]),
#   'color_categories': Counter({'blue': 2,
#            'orange': 2,
#            'red': 1,
#            'white': 1,
#            'gray': 1,
#            'green': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.36848596643518516),
#   'color_variance': np.float64(0.11816126160057151),
#   'edge_density': np.float64(0.1015625),
#   'num_lines': 12,
#   'horizontal_lines': 4,
#   'vertical_lines': 0,
#   'diagonal_lines': 8,
#   'num_shapes': 6,
#   'avg_shape_complexity': np.float64(94.50322327868159),
#   'shape_size_variance': np.float64(86.66666666666667),
#   'horizontal_stripes': 4,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.8059151177832244),
#   'vertical_symmetry': np.float64(0.6690729677287581),
#   'cross_pattern': np.float64(0.5534404077176543),
#   'quarter_diversity': np.float64(0.01392556035893908)},
#  'zm': {'dominant_colors': array([[ 9.85298467e-02,  5.40975521e-01,  8.69913183e-07],
#          [ 7.08688966e-01,  4.04767397e-01, -6.07153217e-18],
#          [-1.94289029e-16, -1.66533454e-16, -5.20417043e-18],
#          [ 8.70588235e-01,  1.25490196e-01,  6.27450980e-02],
#          [ 9.33906423e-01,  4.88738794e-01, -4.33680869e-18],
#          [ 3.11365287e-01,  4.33405955e-01,  9.07770516e-03],
#          [ 4.02962963e-01,  2.20653595e-01,  0.00000000e+00],
#          [ 1.29411765e-01,  6.27450980e-02, -8.67361738e-19]]),
#   'color_proportions': array([0.73372396, 0.01660156, 0.06673177, 0.07340495, 0.07796224,
#          0.01757812, 0.00732422, 0.00667318]),
#   'color_categories': Counter({'orange': 4,
#            'green': 1,
#            'black': 1,
#            'red': 1,
#            'yellow': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.23181423611111107),
#   'color_variance': np.float64(0.0741301340594225),
#   'edge_density': np.float64(0.0302734375),
#   'num_lines': 2,
#   'horizontal_lines': 0,
#   'vertical_lines': 2,
#   'diagonal_lines': 0,
#   'num_shapes': 2,
#   'avg_shape_complexity': np.float64(28.26586527917375),
#   'shape_size_variance': 0,
#   'horizontal_stripes': 0,
#   'vertical_stripes': 3,
#   'stripe_type': 'vertical',
#   'horizontal_symmetry': np.float64(0.9232749523420479),
#   'vertical_symmetry': np.float64(0.8463762935729847),
#   'cross_pattern': np.float64(0.690011782583055),
#   'quarter_diversity': np.float64(7.651362030563053e-05)},
#  'zw': {'dominant_colors': array([[ 8.29867055e-01,  8.23165179e-04,  4.54076367e-04],
#          [ 9.79968839e-01,  8.12715211e-01,  6.25177607e-04],
#          [-1.88737914e-15,  3.91674882e-01, -4.71844785e-16],
#          [ 9.94859516e-01,  9.90364768e-01,  9.90165243e-01],
#          [ 2.42478671e-03,  3.95150427e-03,  1.20740408e-03],
#          [ 3.12850140e-01,  3.15126050e-02,  1.73319328e-02],
#          [ 6.73817762e-01,  5.48558247e-01,  5.29296424e-01],
#          [ 8.38967855e-01,  2.82834026e-01,  1.18521758e-02]]),
#   'color_proportions': array([0.19714355, 0.2442627 , 0.26220703, 0.13195801, 0.09594727,
#          0.02734375, 0.00830078, 0.03283691]),
#   'color_categories': Counter({'red': 3, 'orange': 2, 'green': 2, 'white': 1}),
#   'num_colors': 8,
#   'brightness': np.float64(0.3865344477634804),
#   'color_variance': np.float64(0.18439140621437625),
#   'edge_density': np.float64(0.11083984375),
#   'num_lines': 9,
#   'horizontal_lines': 7,
#   'vertical_lines': 0,
#   'diagonal_lines': 2,
#   'num_shapes': 5,
#   'avg_shape_complexity': np.float64(972.7356083561015),
#   'shape_size_variance': np.float64(264.0625),
#   'horizontal_stripes': 6,
#   'vertical_stripes': 0,
#   'stripe_type': 'horizontal',
#   'horizontal_symmetry': np.float64(0.9833164190155229),
#   'vertical_symmetry': np.float64(0.7847589231004902),
#   'cross_pattern': np.float64(0.6456132159165691),
#   'quarter_diversity': np.float64(0.015693367256187835)}}

# %%
import os
import numpy as np
import pandas as pd
from collections import Counter, defaultdict
import matplotlib.pyplot as plt
import seaborn as sns

class FlagAnalyzer:
    def __init__(self, feature_results):
        """Initialize with results from FlagFeatureExtractor"""
        self.results = feature_results
        self.df = self.create_feature_dataframe()
    
    def create_feature_dataframe(self):
        """Convert feature results to clean pandas DataFrame"""
        rows = []
        
        for country, features in self.results.items():
            row = {
                'country': country,
                # Color features - simplified
                'num_colors': features['num_colors'],
                'brightness': round(float(features['brightness']), 3),
                'primary_colors': self.get_primary_colors(features['color_categories']),
                
                # Pattern features
                'stripe_type': features['stripe_type'],
                'num_horizontal_stripes': features['horizontal_stripes'],
                'num_vertical_stripes': features['vertical_stripes'],
                
                # Symmetry (rounded for readability)
                'h_symmetry': round(float(features['horizontal_symmetry']), 2),
                'v_symmetry': round(float(features['vertical_symmetry']), 2),
                
                # Shape features
                'num_lines': features['num_lines'],
                'num_shapes': features['num_shapes'],
                'edge_density': round(float(features['edge_density']), 3),
                
                # Special patterns
                'has_cross': float(features['cross_pattern']) > 0.8,
                'cross_strength': round(float(features['cross_pattern']), 2),
            }
            rows.append(row)
        
        return pd.DataFrame(rows)
    
    def get_primary_colors(self, color_counter):
        """Get the top 3 most common colors as a string"""
        top_colors = color_counter.most_common(3)
        return ', '.join([color for color, count in top_colors])
    
    def find_similar_flags(self, country_code, top_n=5):
        """Find flags most similar to given country"""
        if country_code not in self.df['country'].values:
            print(f"Country {country_code} not found!")
            return
        
        # Get target flag features
        target = self.df[self.df['country'] == country_code].iloc[0]
        
        # Calculate similarity scores
        similarities = []
        for _, row in self.df.iterrows():
            if row['country'] == country_code:
                continue
                
            score = self.calculate_similarity(target, row)
            similarities.append((row['country'], score))
        
        # Sort and display
        similarities.sort(key=lambda x: x[1], reverse=True)
        
        print(f"\n🏁 FLAGS MOST SIMILAR TO {country_code.upper()}:")
        print("="*50)
        for i, (country, score) in enumerate(similarities[:top_n], 1):
            flag_info = self.df[self.df['country'] == country].iloc[0]
            print(f"{i}. {country.upper()} (similarity: {score:.2f})")
            print(f"   Colors: {flag_info['primary_colors']}")
            print(f"   Pattern: {flag_info['stripe_type']} stripes")
            print(f"   Symmetry: H={flag_info['h_symmetry']}, V={flag_info['v_symmetry']}")
            print()
    
    def calculate_similarity(self, flag1, flag2):
        """Calculate similarity between two flags"""
        score = 0
        
        # Color similarity
        if flag1['primary_colors'] == flag2['primary_colors']:
            score += 3
        elif any(color in flag2['primary_colors'] for color in flag1['primary_colors'].split(', ')):
            score += 1
        
        # Pattern similarity
        if flag1['stripe_type'] == flag2['stripe_type'] and flag1['stripe_type'] != 'none':
            score += 2
        
        # Symmetry similarity
        score += 1 - abs(flag1['h_symmetry'] - flag2['h_symmetry'])
        score += 1 - abs(flag1['v_symmetry'] - flag2['v_symmetry'])
        
        # Cross pattern
        if flag1['has_cross'] and flag2['has_cross']:
            score += 1
        
        # Number of colors
        color_diff = abs(flag1['num_colors'] - flag2['num_colors'])
        score += max(0, 1 - color_diff/5)
        
        return score
    
    def analyze_patterns(self):
        """Analyze common patterns across all flags"""
        print("🎨 FLAG PATTERN ANALYSIS")
        print("="*50)
        
        # Stripe patterns
        stripe_counts = Counter(self.df['stripe_type'])
        print(f"\nStripe Patterns:")
        for pattern, count in stripe_counts.items():
            print(f"  {pattern.title()}: {count} flags")
        
        # Color analysis
        all_colors = []
        for colors_str in self.df['primary_colors']:
            all_colors.extend(colors_str.split(', '))
        color_popularity = Counter(all_colors)
        
        print(f"\nMost Popular Colors:")
        for color, count in color_popularity.most_common(8):
            print(f"  {color.title()}: {count} flags")
        
        # Symmetry analysis
        high_symmetry = self.df[(self.df['h_symmetry'] > 0.9) & (self.df['v_symmetry'] > 0.9)]
        print(f"\nHighly Symmetric Flags ({len(high_symmetry)}):")
        for _, flag in high_symmetry.head(10).iterrows():
            print(f"  {flag['country'].upper()}")
        
        # Cross patterns
        cross_flags = self.df[self.df['has_cross']]
        print(f"\nFlags with Cross Patterns ({len(cross_flags)}):")
        for _, flag in cross_flags.head(10).iterrows():
            print(f"  {flag['country'].upper()} (strength: {flag['cross_strength']})")
    
    def find_flag_families(self):
        """Group flags into families based on shared characteristics"""
        families = defaultdict(list)
        
        # Nordic cross family
        nordic = self.df[(self.df['has_cross']) & (self.df['cross_strength'] > 0.85)]
        if len(nordic) > 0:
            families['Nordic Cross'] = nordic['country'].tolist()
        
        # Tricolor families
        tricolors_h = self.df[(self.df['stripe_type'] == 'horizontal') & 
                             (self.df['num_horizontal_stripes'] == 2)]  # 3 stripes = 2 changes
        if len(tricolors_h) > 0:
            families['Horizontal Tricolor'] = tricolors_h['country'].tolist()
            
        tricolors_v = self.df[(self.df['stripe_type'] == 'vertical') & 
                             (self.df['num_vertical_stripes'] == 2)]
        if len(tricolors_v) > 0:
            families['Vertical Tricolor'] = tricolors_v['country'].tolist()
        
        # Red-white combinations
        red_white = self.df[self.df['primary_colors'].str.contains('red') & 
                           self.df['primary_colors'].str.contains('white')]
        if len(red_white) > 2:
            families['Red & White'] = red_white['country'].tolist()
        
        # Pan-African colors (red, green, yellow/gold)
        pan_african = self.df[self.df['primary_colors'].str.contains('red') & 
                             self.df['primary_colors'].str.contains('green') &
                             (self.df['primary_colors'].str.contains('yellow') | 
                              self.df['primary_colors'].str.contains('orange'))]
        if len(pan_african) > 0:
            families['Pan-African Colors'] = pan_african['country'].tolist()
        
        # Blue-white combinations  
        blue_white = self.df[self.df['primary_colors'].str.contains('blue') & 
                            self.df['primary_colors'].str.contains('white')]
        if len(blue_white) > 2:
            families['Blue & White'] = blue_white['country'].tolist()
        
        print("\n🏁 FLAG FAMILIES")
        print("="*50)
        for family_name, countries in families.items():
            print(f"\n{family_name} ({len(countries)} flags):")
            for country in countries:
                print(f"  {country.upper()}")
    
    def create_summary_table(self, countries=None):
        """Create a clean summary table"""
        df_display = self.df.copy()
        
        if countries:
            df_display = df_display[df_display['country'].isin(countries)]
        
        # Select and rename columns for display
        display_cols = {
            'country': 'Country',
            'primary_colors': 'Colors',
            'stripe_type': 'Stripes',
            'h_symmetry': 'H.Sym',
            'v_symmetry': 'V.Sym',
            'has_cross': 'Cross',
            'num_colors': '#Colors',
            'brightness': 'Bright'
        }
        
        summary = df_display[list(display_cols.keys())].rename(columns=display_cols)
        summary['Country'] = summary['Country'].str.upper()
        
        return summary
    
    def plot_feature_distributions(self):
        """Create visualizations of feature distributions"""
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))
        fig.suptitle('Flag Feature Distributions', fontsize=16)
        
        # Color count distribution
        axes[0,0].hist(self.df['num_colors'], bins=range(1, 11), alpha=0.7)
        axes[0,0].set_title('Number of Colors')
        axes[0,0].set_xlabel('Colors')
        axes[0,0].set_ylabel('Frequency')
        
        # Brightness distribution
        axes[0,1].hist(self.df['brightness'], bins=20, alpha=0.7)
        axes[0,1].set_title('Brightness Distribution')
        axes[0,1].set_xlabel('Brightness')
        axes[0,1].set_ylabel('Frequency')
        
        # Symmetry scatter
        axes[0,2].scatter(self.df['h_symmetry'], self.df['v_symmetry'], alpha=0.6)
        axes[0,2].set_title('Symmetry: Horizontal vs Vertical')
        axes[0,2].set_xlabel('Horizontal Symmetry')
        axes[0,2].set_ylabel('Vertical Symmetry')
        
        # Stripe type counts
        stripe_counts = self.df['stripe_type'].value_counts()
        axes[1,0].bar(stripe_counts.index, stripe_counts.values)
        axes[1,0].set_title('Stripe Patterns')
        axes[1,0].tick_params(axis='x', rotation=45)
        
        # Color popularity
        all_colors = []
        for colors in self.df['primary_colors']:
            all_colors.extend(colors.split(', '))
        color_counts = Counter(all_colors)
        top_colors = dict(color_counts.most_common(8))
        
        axes[1,1].bar(top_colors.keys(), top_colors.values())
        axes[1,1].set_title('Most Popular Colors')
        axes[1,1].tick_params(axis='x', rotation=45)
        
        # Cross pattern strength
        cross_flags = self.df[self.df['has_cross']]
        if len(cross_flags) > 0:
            axes[1,2].hist(cross_flags['cross_strength'], bins=10, alpha=0.7)
            axes[1,2].set_title('Cross Pattern Strength')
            axes[1,2].set_xlabel('Cross Strength')
            axes[1,2].set_ylabel('Frequency')
        
        plt.tight_layout()
        plt.show()

# Usage functions
def quick_analysis(results):
    """Quick analysis of flag features"""
    analyzer = FlagAnalyzer(results)
    
    print("📊 QUICK FLAG ANALYSIS")
    print("="*50)
    print(f"Total flags analyzed: {len(analyzer.df)}")
    print(f"Average colors per flag: {analyzer.df['num_colors'].mean():.1f}")
    print(f"Most symmetric flag: {analyzer.df.loc[analyzer.df['h_symmetry'].idxmax(), 'country'].upper()}")
    print(f"Brightest flag: {analyzer.df.loc[analyzer.df['brightness'].idxmax(), 'country'].upper()}")
    
    analyzer.analyze_patterns()
    analyzer.find_flag_families()
    
    return analyzer

def compare_flags(results, flag1, flag2):
    """Compare two specific flags"""
    analyzer = FlagAnalyzer(results)
    
    if flag1 not in analyzer.df['country'].values or flag2 not in analyzer.df['country'].values:
        print("One or both countries not found!")
        return
    
    f1 = analyzer.df[analyzer.df['country'] == flag1].iloc[0]
    f2 = analyzer.df[analyzer.df['country'] == flag2].iloc[0]
    
    print(f"\n🆚 COMPARING {flag1.upper()} vs {flag2.upper()}")
    print("="*50)
    
    features = ['primary_colors', 'stripe_type', 'h_symmetry', 'v_symmetry', 
                'num_colors', 'brightness', 'has_cross']
    
    for feature in features:
        print(f"{feature:15}: {f1[feature]:20} | {f2[feature]}")
    
    similarity = analyzer.calculate_similarity(f1, f2)
    print(f"\nSimilarity Score: {similarity:.2f}/10")

# Example usage
print("Flag analyzer ready!")
print("\nUsage:")
print("analyzer = quick_analysis(your_feature_results)")
print("analyzer.find_similar_flags('us')")  
print("compare_flags(your_feature_results, 'us', 'uk')")
# Out:
# Flag analyzer ready!
#
# Usage:
# analyzer = quick_analysis(your_feature_results)
# analyzer.find_similar_flags('us')
# compare_flags(your_feature_results, 'us', 'uk')

# %%
analyzer = quick_analysis(extractor.analyze_flag_directory("sovereign_flag_svgs"))
analyzer.find_similar_flags('in')
compare_flags(extractor.analyze_flag_directory("sovereign_flag_svgs"), 'us', 'gb')
# Out:
# Analyzed ad
# Analyzed ae
# Analyzed af
# Analyzed ag
# Analyzed al
# Analyzed am
# Analyzed ao
# Analyzed ar
# Analyzed at
# Analyzed au
# Analyzed az
# Analyzed ba
# Analyzed bb
# Analyzed bd
# Analyzed be
# Analyzed bf
# Analyzed bg
# Analyzed bh
# Analyzed bi
# Analyzed bj
# Analyzed bn
# Analyzed bo
# Analyzed br
# Analyzed bs
# Analyzed bt
# Analyzed bw
# Analyzed by
# Analyzed bz
# Analyzed ca
# Analyzed cd
# Analyzed cf
# Analyzed cg
# Analyzed ch
# Analyzed ci
# Analyzed cl
# Analyzed cm
# Analyzed cn
# Analyzed co
# Analyzed cr
# Analyzed cu
# Analyzed cv
# Analyzed cy
# Analyzed cz
# Analyzed de
# Analyzed dj
# Analyzed dk
# Analyzed dm
# Analyzed do
# Analyzed dz
# Analyzed ec
# Analyzed ee
# Analyzed eg
# Analyzed er
# Analyzed es
# Analyzed et
# Analyzed fi
# Analyzed fj
# Analyzed fm
# Analyzed fr
# Analyzed ga
# Analyzed gb
# Analyzed gd
# Analyzed ge
# Analyzed gh
# Analyzed gm
# Analyzed gn
# Analyzed gq
# Analyzed gr
# Analyzed gt
# Analyzed gw
# Analyzed gy
# Analyzed hn
# Analyzed hr
# Analyzed ht
# Analyzed hu
# Analyzed id
# Analyzed ie
# Analyzed il
# Analyzed in
# Analyzed iq
# Analyzed ir
# Analyzed is
# Analyzed it
# Analyzed jm
# Analyzed jo
# Analyzed jp
# Analyzed ke
# Analyzed kg
# Analyzed kh
# Analyzed ki
# Analyzed km
# Analyzed kn
# Analyzed kp
# Analyzed kr
# Analyzed kw
# Analyzed kz
# Analyzed la
# Analyzed lb
# Analyzed lc
# Analyzed li
# Analyzed lk
# Analyzed lr
# Analyzed ls
# Analyzed lt
# Analyzed lu
# Analyzed lv
# Analyzed ly
# Analyzed ma
# Analyzed mc
# Analyzed md
# Analyzed me
# Analyzed mg
# Analyzed mh
# Analyzed mk
# Analyzed ml
# Analyzed mm
# Analyzed mn
# Analyzed mr
# Analyzed mt
# Analyzed mu
# Analyzed mv
# Analyzed mw
# Analyzed mx
# Analyzed my
# Analyzed mz
# Analyzed na
# Analyzed ne
# Analyzed ng
# Analyzed ni
# Analyzed nl
# Analyzed no
# Analyzed np
# Analyzed nr
# Analyzed nz
# Analyzed om
# Analyzed pa
# Analyzed pe
# Analyzed pg
# Analyzed ph
# Analyzed pk
# Analyzed pl
# Analyzed ps
# Analyzed pt
# Analyzed pw
# Analyzed py
# Analyzed qa
# Analyzed ro
# Analyzed rs
# Analyzed ru
# Analyzed rw
# Analyzed sa
# Analyzed sb
# Analyzed sc
# Analyzed sd
# Analyzed se
# Analyzed sg
# Analyzed si
# Analyzed sk
# Analyzed sl
# Analyzed sm
# Analyzed sn
# Analyzed so
# Analyzed sr
# Analyzed ss
# Analyzed st
# Analyzed sv
# Analyzed sy
# Analyzed sz
# Analyzed td
# Analyzed tg
# Analyzed th
# Analyzed tj
# Analyzed tl
# Analyzed tm
# Analyzed tn
# Analyzed to
# Analyzed tr
# Analyzed tt
# Analyzed tv
# Analyzed tw
# Analyzed tz
# Analyzed ua
# Analyzed ug
# Analyzed us
# Analyzed uy
# Analyzed uz
# Analyzed va
# Analyzed vc
# Analyzed ve
# Analyzed vn
# Analyzed vu
# Analyzed ws
# Analyzed xk
# Analyzed ye
# Analyzed za
# Analyzed zm
# Analyzed zw
# 📊 QUICK FLAG ANALYSIS
# ==================================================
# Total flags analyzed: 197
# Average colors per flag: 7.3
# Most symmetric flag: AR
# Brightest flag: CY
# 🎨 FLAG PATTERN ANALYSIS
# ==================================================
#
# Stripe Patterns:
#   Vertical: 12 flags
#   Horizontal: 77 flags
#   None: 88 flags
#   Both: 20 flags
#
# Most Popular Colors:
#   Red: 143 flags
#   Blue: 124 flags
#   White: 118 flags
#   Orange: 91 flags
#   Green: 36 flags
#   Yellow: 17 flags
#   Gray: 14 flags
#   Purple: 8 flags
#
# Highly Symmetric Flags (51):
#   AL
#   AR
#   AT
#   BB
#   BD
#   BI
#   BR
#   BW
#   BZ
#   CA
#
# Flags with Cross Patterns (66):
#   AL (strength: 0.92)
#   AR (strength: 1.0)
#   AT (strength: 1.0)
#   BB (strength: 0.99)
#   BD (strength: 0.87)
#   BI (strength: 0.99)
#   BR (strength: 0.99)
#   BW (strength: 1.0)
#   BZ (strength: 0.99)
#   CA (strength: 0.99)
#
# 🏁 FLAG FAMILIES
# ==================================================
#
# Nordic Cross (59 flags):
#   AL
#   AR
#   AT
#   BB
#   BD
#   BI
#   BR
#   BW
#   BZ
#   CA
#   CD
#   CH
#   CN
#   CR
#   CY
#   DM
#   DO
#   ES
#   FM
#   GB
#   GD
#   GE
#   GR
#   GT
#   HN
#   IL
#   JM
#   JP
#   KG
#   KH
#   KP
#   KR
#   KZ
#   LA
#   LB
#   LK
#   LV
#   MA
#   ME
#   MH
#   MK
#   MN
#   MR
#   MV
#   NG
#   NI
#   NR
#   PE
#   SA
#   SO
#   SR
#   SV
#   TH
#   TN
#   TR
#   TT
#   UG
#   VN
#   XK
#
# Red & White (82 flags):
#   AG
#   AT
#   AU
#   BG
#   BH
#   BI
#   BN
#   BT
#   BY
#   CA
#   CH
#   CL
#   CU
#   CZ
#   DJ
#   DK
#   DO
#   DZ
#   EG
#   ES
#   FJ
#   FR
#   GB
#   GE
#   GM
#   GQ
#   HR
#   HT
#   HU
#   ID
#   IQ
#   IR
#   IS
#   IT
#   JO
#   JP
#   KE
#   KH
#   KM
#   KP
#   KW
#   LA
#   LB
#   LR
#   LU
#   LV
#   MC
#   MG
#   MT
#   MV
#   MY
#   NA
#   NL
#   NO
#   NZ
#   OM
#   PA
#   PG
#   PL
#   PS
#   PY
#   QA
#   RU
#   SD
#   SG
#   SI
#   SK
#   SS
#   SY
#   TH
#   TJ
#   TL
#   TN
#   TO
#   TR
#   TT
#   TV
#   TW
#   US
#   VA
#   WS
#   YE
#
# Pan-African Colors (10 flags):
#   BF
#   ER
#   ML
#   MM
#   MR
#   MW
#   PT
#   SN
#   ST
#   ZW
#
# Blue & White (67 flags):
#   AE
#   AR
#   AU
#   BA
#   BG
#   BW
#   CF
#   CI
#   CL
#   CU
#   CZ
#   DO
#   DZ
#   FI
#   FJ
#   FM
#   FR
#   GB
#   GQ
#   GR
#   HN
#   HR
#   HT
#   IE
#   IL
#   IQ
#   IS
#   IT
#   JO
#   KI
#   KP
#   KW
#   LA
#   LB
#   LC
#   LR
#   LS
#   LU
#   MG
#   MH
#   MV
#   NA
#   NG
#   NI
#   NL
#   NO
#   NR
#   NZ
#   PA
#   PK
#   PS
#   PY
#   RS
#   RU
#   SA
#   SI
#   SK
#   SL
#   SO
#   SS
#   SV
#   SY
#   TV
#   UY
#   UZ
#   WS
#   XK
#
# 🏁 FLAGS MOST SIMILAR TO IN:
# ==================================================
# 1. MM (similarity: 5.98)
#    Colors: yellow, red, green
#    Pattern: horizontal stripes
#    Symmetry: H=0.76, V=1.0
#
# 2. MW (similarity: 5.98)
#    Colors: red, green, orange
#    Pattern: horizontal stripes
#    Symmetry: H=0.76, V=1.0
#
# 3. TJ (similarity: 5.98)
#    Colors: orange, red, white
#    Pattern: horizontal stripes
#    Symmetry: H=0.76, V=1.0
#
# 4. HR (similarity: 5.97)
#    Colors: red, blue, white
#    Pattern: horizontal stripes
#    Symmetry: H=0.71, V=1.0
#
# 5. AZ (similarity: 5.96)
#    Colors: red, blue, green
#    Pattern: horizontal stripes
#    Symmetry: H=0.77, V=0.99
#
# Analyzed ad
# Analyzed ae
# Analyzed af
# Analyzed ag
# Analyzed al
# Analyzed am
# Analyzed ao
# Analyzed ar
# Analyzed at
# Analyzed au
# Analyzed az
# Analyzed ba
# Analyzed bb
# Analyzed bd
# Analyzed be
# Analyzed bf
# Analyzed bg
# Analyzed bh
# Analyzed bi
# Analyzed bj
# Analyzed bn
# Analyzed bo
# Analyzed br
# Analyzed bs
# Analyzed bt
# Analyzed bw
# Analyzed by
# Analyzed bz
# Analyzed ca
# Analyzed cd
# Analyzed cf
# Analyzed cg
# Analyzed ch
# Analyzed ci
# Analyzed cl
# Analyzed cm
# Analyzed cn
# Analyzed co
# Analyzed cr
# Analyzed cu
# Analyzed cv
# Analyzed cy
# Analyzed cz
# Analyzed de
# Analyzed dj
# Analyzed dk
# Analyzed dm
# Analyzed do
# Analyzed dz
# Analyzed ec
# Analyzed ee
# Analyzed eg
# Analyzed er
# Analyzed es
# Analyzed et
# Analyzed fi
# Analyzed fj
# Analyzed fm
# Analyzed fr
# Analyzed ga
# Analyzed gb
# Analyzed gd
# Analyzed ge
# Analyzed gh
# Analyzed gm
# Analyzed gn
# Analyzed gq
# Analyzed gr
# Analyzed gt
# Analyzed gw
# Analyzed gy
# Analyzed hn
# Analyzed hr
# Analyzed ht
# Analyzed hu
# Analyzed id
# Analyzed ie
# Analyzed il
# Analyzed in
# Analyzed iq
# Analyzed ir
# Analyzed is
# Analyzed it
# Analyzed jm
# Analyzed jo
# Analyzed jp
# Analyzed ke
# Analyzed kg
# Analyzed kh
# Analyzed ki
# Analyzed km
# Analyzed kn
# Analyzed kp
# Analyzed kr
# Analyzed kw
# Analyzed kz
# Analyzed la
# Analyzed lb
# Analyzed lc
# Analyzed li
# Analyzed lk
# Analyzed lr
# Analyzed ls
# Analyzed lt
# Analyzed lu
# Analyzed lv
# Analyzed ly
# Analyzed ma
# Analyzed mc
# Analyzed md
# Analyzed me
# Analyzed mg
# Analyzed mh
# Analyzed mk
# Analyzed ml
# Analyzed mm
# Analyzed mn
# Analyzed mr
# Analyzed mt
# Analyzed mu
# Analyzed mv
# Analyzed mw
# Analyzed mx
# Analyzed my
# Analyzed mz
# Analyzed na
# Analyzed ne
# Analyzed ng
# Analyzed ni
# Analyzed nl
# Analyzed no
# Analyzed np
# Analyzed nr
# Analyzed nz
# Analyzed om
# Analyzed pa
# Analyzed pe
# Analyzed pg
# Analyzed ph
# Analyzed pk
# Analyzed pl
# Analyzed ps
# Analyzed pt
# Analyzed pw
# Analyzed py
# Analyzed qa
# Analyzed ro
# Analyzed rs
# Analyzed ru
# Analyzed rw
# Analyzed sa
# Analyzed sb
# Analyzed sc
# Analyzed sd
# Analyzed se
# Analyzed sg
# Analyzed si
# Analyzed sk
# Analyzed sl
# Analyzed sm
# Analyzed sn
# Analyzed so
# Analyzed sr
# Analyzed ss
# Analyzed st
# Analyzed sv
# Analyzed sy
# Analyzed sz
# Analyzed td
# Analyzed tg
# Analyzed th
# Analyzed tj
# Analyzed tl
# Analyzed tm
# Analyzed tn
# Analyzed to
# Analyzed tr
# Analyzed tt
# Analyzed tv
# Analyzed tw
# Analyzed tz
# Analyzed ua
# Analyzed ug
# Analyzed us
# Analyzed uy
# Analyzed uz
# Analyzed va
# Analyzed vc
# Analyzed ve
# Analyzed vn
# Analyzed vu
# Analyzed ws
# Analyzed xk
# Analyzed ye
# Analyzed za
# Analyzed zm
# Analyzed zw
#
# 🆚 COMPARING US vs GB
# ==================================================
# primary_colors : red, white, purple   | white, red, blue
# stripe_type    : horizontal           | both
# h_symmetry     :                 0.84 | 0.88
# v_symmetry     :                 0.82 | 0.88
# num_colors     :                    8 | 8
# brightness     :                0.595 | 0.521
# has_cross      :                    0 | True
#
# Similarity Score: 3.90/10
